# %%
# Auto reload local files
# %load_ext autoreload
# %autoreload 2
# Make files in src/ available to notebook
import sys
if 'src' not in sys.path:
    sys.path.insert(0, 'src')


import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from technical_signals import TechnicalSignals, percent_change
import datastore as ds

spy_constituents = pd.read_csv('../../data/spy_constituents.csv', header=0)

def test_model(model, X_test, y_test):
    # Predict
    y_predicted = model.predict(X_test)
    # Error and % correct
    loss = np.mean(np.square(y_predicted - y_test))
    correct = ((y_predicted > 0) == (y_test > 0)).sum() / len(y_predicted) * 100
    up = (y_test > 0).sum() / len(y_test) * 100
    print(f'Correctly predicted direction of change {correct}% of the time')
    print(f'Up {up}% of the time')
    print('MSE Loss:', loss)
    print(f'Standard deviation: actual = {np.std(y_test)}, predicted = {np.std(y_predicted)}')
    
    return y_predicted[-1]
    
    
predictions = {}
for ticker in spy_constituents['Symbol']:
    try:
        print('Ticker:', ticker)
        # Download data
        #ds.download_daily_candlesticks([ticker], "2000-01-01", "2023-05-07")
        # Load data
        data = ds.get_daily_candlesticks([ticker], "2000-01-01", "2023-06-06")[ticker]
        # Get technical indicator features for use in forest model
        tsigs = TechnicalSignals(data, predict_window=5)
        X, y, Xy_date = tsigs.toXy()
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
        Xy_test_date = Xy_date.iloc[-y_test.shape[0]:]

        # Train model
        signal_model = RandomForestRegressor()
        signal_model.fit(X_train, y_train)
        # Print predictions
        predictions[ticker] = test_model(signal_model, X_test, y_test)
        print(predictions[ticker], 'by', Xy_test_date.iloc[-1])
    except:
        pass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Ticker: MMM
# Correctly predicted direction of change 65.78014184397163% of the time
# Up 55.14184397163121% of the time
# MSE Loss: 0.7211201220336494
# Standard deviation: actual = 1.0264044628181022, predicted = 0.41597410279053704
# 0.1085549965663619 by 2022-07-13 00:00:00
# Ticker: AOS
# Correctly predicted direction of change 74.64539007092199% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.6050377782655897
# Standard deviation: actual = 0.9995175113236258, predicted = 0.4307244455633435
# 0.23769080400999398 by 2022-07-13 00:00:00
# Ticker: ABT
# Correctly predicted direction of change 73.40425531914893% of the time
# Up 51.06382978723404% of the time
# MSE Loss: 0.7459582312297002
# Standard deviation: actual = 1.0827198390442119, predicted = 0.4117784633033288
# -0.13705220583024558 by 2022-07-13 00:00:00
# Ticker: ABBV
# Correctly predicted direction of change 75.9493670886076% of the time
# Up 47.257383966244724% of the time
# MSE Loss: 0.623214028870385
# Standard deviation: actual = 1.0110487422336738, predicted = 0.4456908465474003
# 0.4448806350746952 by 2022-07-13 00:00:00
# Ticker: ABMD
# Correctly predicted direction of change 73.93617021276596% of the time
# Up 46.808510638297875% of the time
# MSE Loss: 0.6457817606484128
# Standard deviation: actual = 1.0043394714922955, predicted = 0.42188236705358856
# 0.29559054321968625 by 2022-07-13 00:00:00
# Ticker: ACN
# Correctly predicted direction of change 71.61904761904762% of the time
# Up 53.52380952380953% of the time
# MSE Loss: 0.7134666957365026
# Standard deviation: actual = 1.0760811948469335, predicted = 0.4919390165622088
# 0.09315862911150204 by 2022-07-13 00:00:00
# Ticker: ATVI
# Correctly predicted direction of change 72.69503546099291% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.5631765907031275
# Standard deviation: actual = 0.9202949634215501, predicted = 0.40163238725449274
# 0.06209911920353834 by 2022-07-13 00:00:00
# Ticker: ADM
# Correctly predicted direction of change 71.98581560283688% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.7440175145824016
# Standard deviation: actual = 1.0409426803965756, predicted = 0.3678690079585461
# 0.12270212038480216 by 2022-07-13 00:00:00
# Ticker: ADBE
# Correctly predicted direction of change 68.97163120567376% of the time
# Up 51.24113475177305% of the time
# MSE Loss: 0.7276314388652387
# Standard deviation: actual = 1.0437282576293456, predicted = 0.42128334105618975
# -0.06605906705962793 by 2022-07-13 00:00:00
# Ticker: AAP
# Correctly predicted direction of change 71.31782945736434% of the time
# Up 53.875968992248055% of the time
# MSE Loss: 0.7129520312767746
# Standard deviation: actual = 1.017671833707116, predicted = 0.40938163612044054
# 0.5940788081018719 by 2022-07-13 00:00:00
# Ticker: AMD
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 47.87234042553192% of the time
# MSE Loss: 0.8166484212282641
# Standard deviation: actual = 1.0200793943457853, predicted = 0.302225094507248
# -0.5491500386213984 by 2022-07-13 00:00:00
# Ticker: AES
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.5784194922189431
# Standard deviation: actual = 1.0279607313572627, predicted = 0.5035173218717692
# -0.05483617609804279 by 2022-07-13 00:00:00
# Ticker: AFL
# Correctly predicted direction of change 69.14893617021278% of the time
# Up 46.45390070921986% of the time
# MSE Loss: 0.61871026496553
# Standard deviation: actual = 0.9710292669824817, predicted = 0.5452347636766283
# -0.24460569031964258 by 2022-07-13 00:00:00
# Ticker: A
# Correctly predicted direction of change 73.04964539007092% of the time
# Up 52.836879432624116% of the time
# MSE Loss: 0.5606249768976584
# Standard deviation: actual = 0.9983989748763537, predicted = 0.5083107019671661
# -0.062490159739517985 by 2022-07-13 00:00:00
# Ticker: APD
# Correctly predicted direction of change 71.80851063829788% of the time
# Up 47.87234042553192% of the time
# MSE Loss: 0.7079343476179024
# Standard deviation: actual = 1.0326438125204909, predicted = 0.3801370107118382
# -0.3267377029400063 by 2022-07-13 00:00:00
# Ticker: AKAM
# Correctly predicted direction of change 72.87234042553192% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.439276657181197
# Standard deviation: actual = 0.9214261330532177, predicted = 0.47241181043121677
# 0.7098565207512437 by 2022-07-13 00:00:00
# Ticker: ALK
# Correctly predicted direction of change 78.19148936170212% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.5985497398252696
# Standard deviation: actual = 0.9787606579907372, predicted = 0.34291049960456316
# 0.016993272529867324 by 2022-07-13 00:00:00
# Ticker: ALB
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 51.41843971631206% of the time
# MSE Loss: 0.6511985717720107
# Standard deviation: actual = 0.9758594702824803, predicted = 0.3919067289447324
# -0.012892711276835542 by 2022-07-13 00:00:00
# Ticker: ARE
# Correctly predicted direction of change 74.29078014184397% of the time
# Up 52.4822695035461% of the time
# MSE Loss: 0.6038892472370984
# Standard deviation: actual = 0.9595342718629437, predicted = 0.43505592499476714
# 2.956163694808156 by 2022-07-13 00:00:00
# Ticker: ALGN
# Correctly predicted direction of change 76.90875232774674% of the time
# Up 49.534450651769085% of the time
# MSE Loss: 0.6634580142508991
# Standard deviation: actual = 1.0212529111439665, predicted = 0.3875178941886801
# 0.04779079847868456 by 2022-07-13 00:00:00
# Ticker: ALLE
# Correctly predicted direction of change 72.55813953488372% of the time
# Up 50.23255813953489% of the time
# MSE Loss: 0.6678461584543179
# Standard deviation: actual = 1.042768562948973, predicted = 0.4688815602901669
# 0.8823730272923995 by 2022-07-13 00:00:00
# Ticker: LNT
# Correctly predicted direction of change 70.2127659574468% of the time
# Up 54.07801418439716% of the time
# MSE Loss: 0.8426084907755481
# Standard deviation: actual = 1.0080883531018108, predicted = 0.38406457991645837
# 0.08478094628859102 by 2022-07-13 00:00:00
# Ticker: ALL
# Correctly predicted direction of change 69.8581560283688% of the time
# Up 47.87234042553192% of the time
# MSE Loss: 0.6611788964541574
# Standard deviation: actual = 1.0111707732502007, predicted = 0.44794848204689264
# -0.8466262056918926 by 2022-07-13 00:00:00
# Ticker: GOOGL
# Correctly predicted direction of change 72.99107142857143% of the time
# Up 50.66964285714286% of the time
# MSE Loss: 0.630049116332731
# Standard deviation: actual = 1.018295379210893, predicted = 0.41544417340142414
# -0.03891788015093371 by 2022-07-13 00:00:00
# Ticker: GOOG
# Correctly predicted direction of change 73.88392857142857% of the time
# Up 53.125% of the time
# MSE Loss: 0.6357338530887898
# Standard deviation: actual = 1.0182173927401756, predicted = 0.4178672432976896
# 0.01515113832848189 by 2022-07-13 00:00:00
# Ticker: MO
# Correctly predicted direction of change 75.70921985815603% of the time
# Up 52.659574468085104% of the time
# MSE Loss: 1.983052858719437
# Standard deviation: actual = 1.589332291519573, predicted = 0.4644139712806124
# 0.581754060505954 by 2022-07-13 00:00:00
# Ticker: AMZN
# Correctly predicted direction of change 72.87234042553192% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.7682424835341459
# Standard deviation: actual = 1.1315349836964939, predicted = 0.44828499905922226
# -0.3308722134552671 by 2022-07-13 00:00:00
# Ticker: AMCR
# Ticker: AEE
# Correctly predicted direction of change 75.0% of the time
# Up 51.95035460992907% of the time
# MSE Loss: 0.5785928470250619
# Standard deviation: actual = 0.9507323952968266, predicted = 0.38293899626003625
# 0.2103883280856688 by 2022-07-13 00:00:00
# Ticker: AAL
# Correctly predicted direction of change 78.33333333333333% of the time
# Up 47.85714285714286% of the time
# MSE Loss: 0.500048950115848
# Standard deviation: actual = 1.0059462898354001, predicted = 0.47214054527454546
# 0.023293229318297692 by 2022-07-13 00:00:00
# Ticker: AEP
# Correctly predicted direction of change 70.74468085106383% of the time
# Up 52.659574468085104% of the time
# MSE Loss: 0.73309889401987
# Standard deviation: actual = 1.081452512376981, predicted = 0.5143491500813396
# 0.25289542419626987 by 2022-07-13 00:00:00
# Ticker: AXP
# Correctly predicted direction of change 71.27659574468085% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.642445574981154
# Standard deviation: actual = 1.0599656400614474, predicted = 0.5221175843893067
# -0.29635192385111286 by 2022-07-13 00:00:00
# Ticker: AIG
# Correctly predicted direction of change 71.45390070921985% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.19838913445946774
# Standard deviation: actual = 0.6723945669060162, predicted = 0.5178956382122796
# -0.047098097452236025 by 2022-07-13 00:00:00
# Ticker: AMT
# Correctly predicted direction of change 70.2127659574468% of the time
# Up 48.04964539007092% of the time
# MSE Loss: 0.6237212210868031
# Standard deviation: actual = 1.1677776645710938, predicted = 0.7898458886194616
# -0.03715030299147904 by 2022-07-13 00:00:00
# Ticker: AWK
# Correctly predicted direction of change 75.21126760563381% of the time
# Up 56.61971830985916% of the time
# MSE Loss: 0.6157507008364761
# Standard deviation: actual = 0.9603803989535994, predicted = 0.4171351051461899
# -0.7584744172338915 by 2022-07-13 00:00:00
# Ticker: AMP
# Correctly predicted direction of change 71.19047619047619% of the time
# Up 52.142857142857146% of the time
# MSE Loss: 0.7097379271648638
# Standard deviation: actual = 1.0992662601796772, predicted = 0.4850268071452014
# 0.06893552290952033 by 2022-07-13 00:00:00
# Ticker: ABC
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 47.340425531914896% of the time
# MSE Loss: 0.6263487982465243
# Standard deviation: actual = 1.0134176472046907, predicted = 0.4668890649261026
# -0.028121532138796073 by 2022-07-13 00:00:00
# Ticker: AME
# Correctly predicted direction of change 67.73049645390071% of the time
# Up 52.836879432624116% of the time
# MSE Loss: 0.8116349273009437
# Standard deviation: actual = 1.0772985585779944, predicted = 0.35832559088775356
# -0.32846107184364004 by 2022-07-13 00:00:00
# Ticker: AMGN
# Correctly predicted direction of change 71.63120567375887% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.7471473933980319
# Standard deviation: actual = 1.0748331853504434, predicted = 0.3899737160723057
# -0.2535317021780796 by 2022-07-13 00:00:00
# Ticker: APH
# Correctly predicted direction of change 76.06382978723404% of the time
# Up 51.24113475177305% of the time
# MSE Loss: 0.888824169558996
# Standard deviation: actual = 1.0915638673052062, predicted = 0.4275142855443006
# 0.07166996562531552 by 2022-07-13 00:00:00
# Ticker: ADI
# Correctly predicted direction of change 70.74468085106383% of the time
# Up 47.695035460992905% of the time
# MSE Loss: 0.7093675170329043
# Standard deviation: actual = 0.9614804450326087, predicted = 0.33222439632609374
# -0.17255561876049302 by 2022-07-13 00:00:00
# Ticker: ANSS
# Correctly predicted direction of change 69.68085106382979% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.6124958392573245
# Standard deviation: actual = 0.9575687453869967, predicted = 0.36690072666247986
# 0.08914440074089848 by 2022-07-13 00:00:00
# Ticker: ANTM
# Correctly predicted direction of change 72.2007722007722% of the time
# Up 51.35135135135135% of the time
# MSE Loss: 0.6518932939918668
# Standard deviation: actual = 1.0279342793802992, predicted = 0.3878141932369994
# 0.5087246713560841 by 2022-07-12 00:00:00
# Ticker: AON
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 50.0% of the time
# MSE Loss: 0.6246451495155684
# Standard deviation: actual = 0.9813750086558035, predicted = 0.40085081297239655
# -0.1452767337658728 by 2022-07-13 00:00:00
# Ticker: APA
# Correctly predicted direction of change 73.22695035460993% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.5200684044788579
# Standard deviation: actual = 0.9389612204904655, predicted = 0.5069362979434285
# 0.24522428907525853 by 2022-07-13 00:00:00
# Ticker: AAPL
# Correctly predicted direction of change 76.41843971631207% of the time
# Up 51.95035460992907% of the time
# MSE Loss: 0.6211271429391358
# Standard deviation: actual = 1.0107025910906, predicted = 0.4262595139342839
# -0.01314064018053682 by 2022-07-13 00:00:00
# Ticker: AMAT
# Correctly predicted direction of change 67.02127659574468% of the time
# Up 50.0% of the time
# MSE Loss: 1.053344215298659
# Standard deviation: actual = 1.1241048529982225, predicted = 0.3003294032070065
# -0.06489599184898318 by 2022-07-13 00:00:00
# Ticker: APTV
# Correctly predicted direction of change 72.83018867924528% of the time
# Up 53.9622641509434% of the time
# MSE Loss: 0.5664049942145363
# Standard deviation: actual = 1.0008749877076204, predicted = 0.44055548474687445
# 0.1169208919045045 by 2022-07-13 00:00:00
# Ticker: ANET
# Correctly predicted direction of change 72.13930348258707% of the time
# Up 47.76119402985074% of the time
# MSE Loss: 0.46075316592638893
# Standard deviation: actual = 0.8759462104001886, predicted = 0.46510255439905235
# 0.5680634539797494 by 2022-07-13 00:00:00
# Ticker: AJG
# Correctly predicted direction of change 75.0% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.6283264109424379
# Standard deviation: actual = 0.951343873015329, predicted = 0.42951733175917767
# 0.09645704763613634 by 2022-07-13 00:00:00
# Ticker: AIZ
# Correctly predicted direction of change 72.66811279826464% of the time
# Up 51.40997830802603% of the time
# MSE Loss: 0.5913099525763895
# Standard deviation: actual = 1.0615287268670088, predicted = 0.5983863680944795
# -0.05867327163035996 by 2022-07-13 00:00:00
# Ticker: T
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.543011627406357
# Standard deviation: actual = 1.008992258859399, predicted = 0.4534400577412146
# 0.2174737159980416 by 2022-07-13 00:00:00
# Ticker: ATO
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.7310955770828161
# Standard deviation: actual = 1.0349875519455844, predicted = 0.4557057605316582
# 0.9385581211375519 by 2022-07-13 00:00:00
# Ticker: ADSK
# Correctly predicted direction of change 75.35460992907801% of the time
# Up 46.808510638297875% of the time
# MSE Loss: 0.6575210781861506
# Standard deviation: actual = 1.026660174115781, predicted = 0.4162949168185382
# 0.046519788885857345 by 2022-07-13 00:00:00
# Ticker: ADP
# Correctly predicted direction of change 73.93617021276596% of the time
# Up 53.54609929078015% of the time
# MSE Loss: 0.6818281358204893
# Standard deviation: actual = 0.9977074651976644, predicted = 0.4347628087316245
# -0.10865521638483751 by 2022-07-13 00:00:00
# Ticker: AZO
# Correctly predicted direction of change 71.98581560283688% of the time
# Up 50.35460992907801% of the time
# MSE Loss: 0.7615348112662303
# Standard deviation: actual = 1.099861928169892, predicted = 0.44982659346755766
# -0.24628577083720113 by 2022-07-13 00:00:00
# Ticker: AVB
# Correctly predicted direction of change 72.69503546099291% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.52020483812611
# Standard deviation: actual = 0.8875056782993103, predicted = 0.39775211759045
# 0.22279034588987884 by 2022-07-13 00:00:00
# Ticker: AVY
# Correctly predicted direction of change 69.68085106382979% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.7287918543414916
# Standard deviation: actual = 1.026828290308394, predicted = 0.40247521998148844
# 0.22532431903720906 by 2022-07-13 00:00:00
# Ticker: BKR
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 48.226950354609926% of the time
# MSE Loss: 0.5134117162167271
# Standard deviation: actual = 0.9607895754330449, predicted = 0.4282704161323914
# -0.046243198750244296 by 2022-07-13 00:00:00
# Ticker: BLL
# Correctly predicted direction of change 80.3225806451613% of the time
# Up 50.967741935483865% of the time
# MSE Loss: 0.6836433306455963
# Standard deviation: actual = 1.1107608968224227, predicted = 0.44448742945966047
# -0.2625753502036343 by 2022-06-15 00:00:00
# Ticker: BAC
# Correctly predicted direction of change 77.30496453900709% of the time
# Up 53.191489361702125% of the time
# MSE Loss: 0.6138820046140693
# Standard deviation: actual = 1.0743182321074947, predicted = 0.525976912179695
# -0.1998017947820185 by 2022-07-13 00:00:00
# Ticker: BBWI
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 48.40425531914894% of the time
# MSE Loss: 0.6428104376658911
# Standard deviation: actual = 0.9979215120672911, predicted = 0.3969523301304329
# 0.41815078969960245 by 2022-07-13 00:00:00
# Ticker: BAX
# Correctly predicted direction of change 72.3404255319149% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.8132795567697723
# Standard deviation: actual = 1.110825719524234, predicted = 0.42934418487677756
# 0.5697038090916053 by 2022-07-13 00:00:00
# Ticker: BDX
# Correctly predicted direction of change 66.13475177304964% of the time
# Up 52.659574468085104% of the time
# MSE Loss: 0.7347407745492626
# Standard deviation: actual = 1.0254078725151592, predicted = 0.4214980986418424
# 0.21806669505821039 by 2022-07-13 00:00:00
# Ticker: BRK.B
# Ticker: BBY
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 46.808510638297875% of the time
# MSE Loss: 0.6140660065408412
# Standard deviation: actual = 0.978808799923945, predicted = 0.3903972775633598
# 0.2719001358169311 by 2022-07-13 00:00:00
# Ticker: BIO
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 41.48936170212766% of the time
# MSE Loss: 0.6237202203752326
# Standard deviation: actual = 0.9937948354832461, predicted = 0.43548592194518154
# 0.5470498900686973 by 2022-07-13 00:00:00
# Ticker: TECH
# Correctly predicted direction of change 68.08510638297872% of the time
# Up 49.11347517730496% of the time
# MSE Loss: 0.8183253263638972
# Standard deviation: actual = 1.029864254743789, predicted = 0.33985727933327525
# 0.6000074823898836 by 2022-07-13 00:00:00
# Ticker: BIIB
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.6381456745906862
# Standard deviation: actual = 0.9248499976415068, predicted = 0.34674818909747723
# 0.010995861110068556 by 2022-07-13 00:00:00
# Ticker: BLK
# Correctly predicted direction of change 69.50354609929079% of the time
# Up 50.0% of the time
# MSE Loss: 0.7422398002930903
# Standard deviation: actual = 0.9532650927505749, predicted = 0.3519170446742294
# 0.18584130962418757 by 2022-07-13 00:00:00
# Ticker: BK
# Correctly predicted direction of change 75.53191489361703% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6501678095633755
# Standard deviation: actual = 1.0454854718219722, predicted = 0.4115028689091131
# 0.04606240198275882 by 2022-07-13 00:00:00
# Ticker: BA
# Correctly predicted direction of change 73.04964539007092% of the time
# Up 48.758865248226954% of the time
# MSE Loss: 0.6491935615678166
# Standard deviation: actual = 1.2019323850040446, predicted = 0.6216574204865574
# 0.1679276905595687 by 2022-07-13 00:00:00
# Ticker: BKNG
# Correctly predicted direction of change 74.46808510638297% of the time
# Up 50.0% of the time
# MSE Loss: 0.6879651312141692
# Standard deviation: actual = 1.0576229655023608, predicted = 0.4122326483983815
# 0.07131098173913994 by 2022-07-13 00:00:00
# Ticker: BWA
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.6696890160516229
# Standard deviation: actual = 0.9804768634727279, predicted = 0.3725676658893938
# -0.15415887080279578 by 2022-07-13 00:00:00
# Ticker: BXP
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 51.24113475177305% of the time
# MSE Loss: 0.664745273641262
# Standard deviation: actual = 0.9464907717079155, predicted = 0.4347174600011837
# 0.02495642749892009 by 2022-07-13 00:00:00
# Ticker: BSX
# Correctly predicted direction of change 71.98581560283688% of the time
# Up 53.01418439716312% of the time
# MSE Loss: 0.6972483256869139
# Standard deviation: actual = 0.96107131640095, predicted = 0.37012794014640105
# 0.47715192881251733 by 2022-07-13 00:00:00
# Ticker: BMY
# Correctly predicted direction of change 71.63120567375887% of the time
# Up 53.72340425531915% of the time
# MSE Loss: 0.5894153629964538
# Standard deviation: actual = 0.9802490597322635, predicted = 0.4221721316697755
# -0.17655734853147198 by 2022-07-13 00:00:00
# Ticker: AVGO
# Correctly predicted direction of change 75.23219814241486% of the time
# Up 52.94117647058824% of the time
# MSE Loss: 0.9095288694449752
# Standard deviation: actual = 1.2050175628046638, predicted = 0.4221395128022818
# 0.0687208935773897 by 2022-07-13 00:00:00
# Ticker: BR
# Correctly predicted direction of change 71.72774869109948% of the time
# Up 49.73821989528796% of the time
# MSE Loss: 0.5658581326330288
# Standard deviation: actual = 0.9761690407295972, predicted = 0.43473008190646273
# 0.6562237462693471 by 2022-07-13 00:00:00
# Ticker: BRO
# Correctly predicted direction of change 75.53191489361703% of the time
# Up 53.191489361702125% of the time
# MSE Loss: 0.5840687465783724
# Standard deviation: actual = 0.9775747472883551, predicted = 0.40828857067619617
# -0.03396923156191199 by 2022-07-13 00:00:00
# Ticker: BF.B
# Ticker: CHRW
# Correctly predicted direction of change 68.79432624113475% of the time
# Up 51.06382978723404% of the time
# MSE Loss: 0.6677050898463393
# Standard deviation: actual = 1.004274259032132, predicted = 0.4116237257575033
# -0.09017441942849581 by 2022-07-13 00:00:00
# Ticker: CDNS
# Correctly predicted direction of change 73.93617021276596% of the time
# Up 55.49645390070922% of the time
# MSE Loss: 0.6077344736976915
# Standard deviation: actual = 0.9756934499965827, predicted = 0.38410149641777264
# -0.3823014252908547 by 2022-07-13 00:00:00
# Ticker: CZR
# Correctly predicted direction of change 74.74226804123711% of the time
# Up 40.72164948453608% of the time
# MSE Loss: 0.43150146743980733
# Standard deviation: actual = 0.8151590324652213, predicted = 0.4197831614913573
# -0.21942337362310912 by 2022-07-13 00:00:00
# Ticker: CPB
# Correctly predicted direction of change 71.98581560283688% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.9380449740062979
# Standard deviation: actual = 1.0928789047224754, predicted = 0.36043131824895897
# 0.11658769759280314 by 2022-07-13 00:00:00
# Ticker: COF
# Correctly predicted direction of change 70.0354609929078% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.5950757708197238
# Standard deviation: actual = 0.9866412363966732, predicted = 0.4588537083464758
# 0.598157397497362 by 2022-07-13 00:00:00
# Ticker: CAH
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.881562481640167
# Standard deviation: actual = 1.111621139821859, predicted = 0.33949339774596143
# -0.21158927740586453 by 2022-07-13 00:00:00
# Ticker: KMX
# Correctly predicted direction of change 69.8581560283688% of the time
# Up 46.09929078014184% of the time
# MSE Loss: 0.5057003376064204
# Standard deviation: actual = 0.8823878275088698, predicted = 0.4062048185977904
# -0.3304122096681326 by 2022-07-13 00:00:00
# Ticker: CCL
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 47.695035460992905% of the time
# MSE Loss: 0.5288956474669311
# Standard deviation: actual = 1.0200864617261043, predicted = 0.5033914905084762
# 0.042902890169669076 by 2022-07-13 00:00:00
# Ticker: CARR
# Correctly predicted direction of change 65.45454545454545% of the time
# Up 58.18181818181818% of the time
# MSE Loss: 0.6796655484698269
# Standard deviation: actual = 0.9389166570666093, predicted = 0.583957209777907
# 2.1770484304583153 by 2022-07-13 00:00:00
# Ticker: CTLT
# Correctly predicted direction of change 78.1725888324873% of the time
# Up 49.746192893401016% of the time
# MSE Loss: 0.5839590432774076
# Standard deviation: actual = 1.0393284357164803, predicted = 0.4678489980931272
# 0.17834080857410786 by 2022-07-13 00:00:00
# Ticker: CAT
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.6615733437389177
# Standard deviation: actual = 0.9525548655491191, predicted = 0.3349203432908649
# -0.35877209472812027 by 2022-07-13 00:00:00
# Ticker: CBOE
# Correctly predicted direction of change 78.07308970099668% of the time
# Up 48.50498338870432% of the time
# MSE Loss: 0.5217294955597607
# Standard deviation: actual = 0.9239961330770372, predicted = 0.45124063692962735
# 0.07382169523973679 by 2022-07-13 00:00:00
# Ticker: CBRE
# Correctly predicted direction of change 76.32743362831859% of the time
# Up 53.09734513274337% of the time
# MSE Loss: 0.49861480442103107
# Standard deviation: actual = 0.9432716470881938, predicted = 0.39721563345929173
# -0.26077482976281435 by 2022-07-13 00:00:00
# Ticker: CDW
# Correctly predicted direction of change 76.44444444444444% of the time
# Up 52.44444444444445% of the time
# MSE Loss: 0.7753269685158852
# Standard deviation: actual = 1.0579730938914804, predicted = 0.35607590354892427
# -0.26534578069900777 by 2022-07-13 00:00:00
# Ticker: CE
# Correctly predicted direction of change 72.08237986270024% of the time
# Up 50.57208237986271% of the time
# MSE Loss: 0.5464329397936791
# Standard deviation: actual = 0.9784458985768255, predicted = 0.4933142104896059
# 0.026664009308540258 by 2022-07-13 00:00:00
# Ticker: CNC
# Correctly predicted direction of change 70.09708737864078% of the time
# Up 50.679611650485434% of the time
# MSE Loss: 0.7512415853841132
# Standard deviation: actual = 1.0315748603585795, predicted = 0.3858135131811052
# -0.08443909542424718 by 2022-07-13 00:00:00
# Ticker: CNP
# Correctly predicted direction of change 68.97163120567376% of the time
# Up 53.36879432624113% of the time
# MSE Loss: 0.48304562237701515
# Standard deviation: actual = 0.8664832451143757, predicted = 0.37695814424194496
# 0.5544639522592614 by 2022-07-13 00:00:00
# Ticker: CDAY
# Correctly predicted direction of change 68.93203883495146% of the time
# Up 57.28155339805825% of the time
# MSE Loss: 0.7594968094814171
# Standard deviation: actual = 1.0551808849277797, predicted = 0.3951821024690123
# 0.03715394692261757 by 2022-07-13 00:00:00
# Ticker: CERN
# Correctly predicted direction of change 70.23172905525847% of the time
# Up 51.515151515151516% of the time
# MSE Loss: 0.8446668357480298
# Standard deviation: actual = 1.100484988305085, predicted = 0.39731673465942285
# -0.0197504140013561 by 2022-06-07 00:00:00
# Ticker: CF
# Correctly predicted direction of change 74.23167848699764% of the time
# Up 48.93617021276596% of the time
# MSE Loss: 0.6440148600036364
# Standard deviation: actual = 1.020451634466992, predicted = 0.4129845408718722
# 0.16020823429970757 by 2022-07-13 00:00:00
# Ticker: CRL
# Correctly predicted direction of change 71.73913043478261% of the time
# Up 51.81159420289855% of the time
# MSE Loss: 0.5612033712543998
# Standard deviation: actual = 1.0115099423977594, predicted = 0.5177191544900654
# 0.09485185087703804 by 2022-07-13 00:00:00
# Ticker: SCHW
# Correctly predicted direction of change 66.31205673758865% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.7458131081151516
# Standard deviation: actual = 0.992220794895548, predicted = 0.34240501503371995
# -0.21962762383161913 by 2022-07-13 00:00:00
# Ticker: CHTR
# Correctly predicted direction of change 73.71794871794873% of the time
# Up 45.19230769230769% of the time
# MSE Loss: 0.6528604947190958
# Standard deviation: actual = 0.9688788340846303, predicted = 0.3739123758742564
# -0.42563730522669885 by 2022-07-13 00:00:00
# Ticker: CVX
# Correctly predicted direction of change 69.32624113475178% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.5942453071959953
# Standard deviation: actual = 0.9157436018986689, predicted = 0.38693669263055236
# 0.8707969053295226 by 2022-07-13 00:00:00
# Ticker: CMG
# Correctly predicted direction of change 75.4257907542579% of the time
# Up 48.175182481751825% of the time
# MSE Loss: 0.5138371143445574
# Standard deviation: actual = 0.9398739795246323, predicted = 0.40786217150006077
# 0.38442076139466125 by 2022-07-13 00:00:00
# Ticker: CB
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 47.695035460992905% of the time
# MSE Loss: 0.6879656840415213
# Standard deviation: actual = 1.0705399881652142, predicted = 0.4898435229127727
# -0.07976770642764508 by 2022-07-13 00:00:00
# Ticker: CHD
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 48.93617021276596% of the time
# MSE Loss: 0.6354520354559341
# Standard deviation: actual = 0.9270048819886104, predicted = 0.33352194750177866
# -0.23363063584819382 by 2022-07-13 00:00:00
# Ticker: CI
# Correctly predicted direction of change 69.14893617021278% of the time
# Up 48.40425531914894% of the time
# MSE Loss: 0.6773682508681468
# Standard deviation: actual = 0.9804537715792778, predicted = 0.3787133612819971
# 0.0006328563293919884 by 2022-07-13 00:00:00
# Ticker: CINF
# Correctly predicted direction of change 69.32624113475178% of the time
# Up 54.60992907801418% of the time
# MSE Loss: 0.580755821395152
# Standard deviation: actual = 0.9550901964017547, predicted = 0.4365806097476686
# -0.1328888890971992 by 2022-07-13 00:00:00
# Ticker: CTAS
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 53.01418439716312% of the time
# MSE Loss: 0.7235764552932586
# Standard deviation: actual = 1.0598977358764214, predicted = 0.42691685623989906
# -0.10212116008510413 by 2022-07-13 00:00:00
# Ticker: CSCO
# Correctly predicted direction of change 74.64539007092199% of the time
# Up 53.90070921985816% of the time
# MSE Loss: 0.6203082270758834
# Standard deviation: actual = 0.9892686159467253, predicted = 0.4408955476786641
# -0.5519922991709026 by 2022-07-13 00:00:00
# Ticker: C
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 51.24113475177305% of the time
# MSE Loss: 0.3546381413417835
# Standard deviation: actual = 0.7300030041716893, predicted = 0.34637859111907293
# 0.14330348408988472 by 2022-07-13 00:00:00
# Ticker: CFG
# Correctly predicted direction of change 79.27461139896373% of the time
# Up 47.66839378238342% of the time
# MSE Loss: 0.5970786140124816
# Standard deviation: actual = 1.0118757538441414, predicted = 0.5354768423855787
# -0.028063397382932922 by 2022-07-13 00:00:00
# Ticker: CTXS
# Correctly predicted direction of change 71.63120567375887% of the time
# Up 53.54609929078015% of the time
# MSE Loss: 0.7097760025648787
# Standard deviation: actual = 1.009107149547122, predicted = 0.3928675118834672
# 0.04391031335496343 by 2022-07-13 00:00:00
# Ticker: CLX
# Correctly predicted direction of change 70.39007092198581% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.5690831257199104
# Standard deviation: actual = 0.9723983041449066, predicted = 0.4458403993861554
# -0.03584830818449825 by 2022-07-13 00:00:00
# Ticker: CME
# Correctly predicted direction of change 73.06122448979592% of the time
# Up 50.816326530612244% of the time
# MSE Loss: 0.5975859488516733
# Standard deviation: actual = 0.981261216115958, predicted = 0.43906238947466686
# 0.19020335595933904 by 2022-07-13 00:00:00
# Ticker: CMS
# Correctly predicted direction of change 75.177304964539% of the time
# Up 57.26950354609929% of the time
# MSE Loss: 0.6354551160220487
# Standard deviation: actual = 0.986574809440353, predicted = 0.4133230739022473
# -0.0792778767857185 by 2022-07-13 00:00:00
# Ticker: KO
# Correctly predicted direction of change 72.3404255319149% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.6551584532089308
# Standard deviation: actual = 0.9665547322127023, predicted = 0.3801909929183655
# 0.19887798650156058 by 2022-07-13 00:00:00
# Ticker: CTSH
# Correctly predicted direction of change 68.43971631205675% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.7927622686148603
# Standard deviation: actual = 1.0768436201189575, predicted = 0.4379196722649478
# -0.17075824892658908 by 2022-07-13 00:00:00
# Ticker: CL
# Correctly predicted direction of change 65.0709219858156% of the time
# Up 48.758865248226954% of the time
# MSE Loss: 0.7914657215514187
# Standard deviation: actual = 1.082461117221967, predicted = 0.444274650465713
# -0.029238333513488212 by 2022-07-13 00:00:00
# Ticker: CMCSA
# Correctly predicted direction of change 75.70921985815603% of the time
# Up 51.06382978723404% of the time
# MSE Loss: 0.5361458479457561
# Standard deviation: actual = 0.922782583603429, predicted = 0.4235209190704076
# 0.3492143388432135 by 2022-07-13 00:00:00
# Ticker: CMA
# Correctly predicted direction of change 69.8581560283688% of the time
# Up 51.95035460992907% of the time
# MSE Loss: 0.5267824729223366
# Standard deviation: actual = 0.9488810068282203, predicted = 0.4262574992643828
# 0.8933218526251311 by 2022-07-13 00:00:00
# Ticker: CAG
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 54.25531914893617% of the time
# MSE Loss: 0.5941891352688989
# Standard deviation: actual = 0.9525513185603784, predicted = 0.40690628004399093
# 0.09424053858272446 by 2022-07-13 00:00:00
# Ticker: COP
# Correctly predicted direction of change 71.98581560283688% of the time
# Up 50.35460992907801% of the time
# MSE Loss: 0.6583382597371971
# Standard deviation: actual = 1.0221292192131581, predicted = 0.4269228854387373
# -0.3066215396991806 by 2022-07-13 00:00:00
# Ticker: ED
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.7081576439277517
# Standard deviation: actual = 1.038738285359596, predicted = 0.3999835254727978
# -0.2639599984242346 by 2022-07-13 00:00:00
# Ticker: STZ
# Correctly predicted direction of change 70.92198581560284% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.6836476205475707
# Standard deviation: actual = 0.9609407438899873, predicted = 0.3264987202773956
# -0.54253379538277 by 2022-07-13 00:00:00
# Ticker: CPRT
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.8843377129730832
# Standard deviation: actual = 1.150616496809469, predicted = 0.4057282022922261
# 0.4131060242613989 by 2022-07-13 00:00:00
# Ticker: GLW
# Correctly predicted direction of change 75.88652482269504% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.4905081620005624
# Standard deviation: actual = 0.9641565156375153, predicted = 0.5185708831175609
# -0.05436263213806963 by 2022-07-13 00:00:00
# Ticker: CTVA
# Correctly predicted direction of change 80.26315789473685% of the time
# Up 43.42105263157895% of the time
# MSE Loss: 0.5942014832497127
# Standard deviation: actual = 0.9534123152394159, predicted = 0.45883501435921037
# -0.1689753717211354 by 2022-07-13 00:00:00
# Ticker: COST
# Correctly predicted direction of change 73.22695035460993% of the time
# Up 53.01418439716312% of the time
# MSE Loss: 0.576104246665701
# Standard deviation: actual = 0.9170611252855105, predicted = 0.3334503507258566
# -0.2164470659228211 by 2022-07-13 00:00:00
# Ticker: CTRA
# Correctly predicted direction of change 74.29078014184397% of the time
# Up 48.04964539007092% of the time
# MSE Loss: 0.7114267446934488
# Standard deviation: actual = 1.0485575504091145, predicted = 0.41149853274461146
# -0.6187510316166454 by 2022-07-13 00:00:00
# Ticker: CCI
# Correctly predicted direction of change 71.63120567375887% of the time
# Up 50.35460992907801% of the time
# MSE Loss: 0.6251801512309815
# Standard deviation: actual = 1.1258031414580971, predicted = 0.5384784098744787
# -0.22211033987737291 by 2022-07-13 00:00:00
# Ticker: CSX
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.7542376862290231
# Standard deviation: actual = 0.9727631665955793, predicted = 0.2951648870666216
# 0.2498664698735528 by 2022-07-13 00:00:00
# Ticker: CMI
# Correctly predicted direction of change 70.39007092198581% of the time
# Up 50.0% of the time
# MSE Loss: 0.6150012007828272
# Standard deviation: actual = 0.9498999092826184, predicted = 0.3807771353803554
# -0.11610844698852692 by 2022-07-13 00:00:00
# Ticker: CVS
# Correctly predicted direction of change 70.0354609929078% of the time
# Up 52.4822695035461% of the time
# MSE Loss: 0.6813565868188688
# Standard deviation: actual = 0.957101125978898, predicted = 0.330078017539772
# 0.1545989551912726 by 2022-07-13 00:00:00
# Ticker: DHI
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 46.45390070921986% of the time
# MSE Loss: 0.5630991913658081
# Standard deviation: actual = 0.9214688559846287, predicted = 0.3797180069705132
# -0.5666653745635329 by 2022-07-13 00:00:00
# Ticker: DHR
# Correctly predicted direction of change 67.73049645390071% of the time
# Up 50.0% of the time
# MSE Loss: 0.6825973066088556
# Standard deviation: actual = 0.9502088448079531, predicted = 0.3057815452878315
# 0.061769560506160115 by 2022-07-13 00:00:00
# Ticker: DRI
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 48.758865248226954% of the time
# MSE Loss: 0.5351602648234945
# Standard deviation: actual = 0.8901786892858289, predicted = 0.377395688203817
# -0.056654527272330835 by 2022-07-13 00:00:00
# Ticker: DVA
# Correctly predicted direction of change 73.40425531914893% of the time
# Up 48.226950354609926% of the time
# MSE Loss: 0.46127159650924504
# Standard deviation: actual = 0.9570699062262009, predicted = 0.555645106929833
# 0.15540911396495094 by 2022-07-13 00:00:00
# Ticker: DE
# Correctly predicted direction of change 71.45390070921985% of the time
# Up 54.25531914893617% of the time
# MSE Loss: 0.6038858917335094
# Standard deviation: actual = 0.9307827556050576, predicted = 0.3706564574601716
# 0.14371491205250733 by 2022-07-13 00:00:00
# Ticker: DAL
# Correctly predicted direction of change 74.21052631578947% of the time
# Up 46.05263157894737% of the time
# MSE Loss: 0.7017688826497671
# Standard deviation: actual = 1.0593692650993964, predicted = 0.5089392925918852
# 0.29769007685119186 by 2022-07-13 00:00:00
# Ticker: XRAY
# Correctly predicted direction of change 67.02127659574468% of the time
# Up 49.11347517730496% of the time
# MSE Loss: 0.6199464133787941
# Standard deviation: actual = 0.9647670990465702, predicted = 0.3910745732888905
# -0.010810509220557025 by 2022-07-13 00:00:00
# Ticker: DVN
# Correctly predicted direction of change 71.63120567375887% of the time
# Up 47.5177304964539% of the time
# MSE Loss: 0.7184906857551155
# Standard deviation: actual = 1.0755177576326673, predicted = 0.5071419672446242
# -0.036609933226239906 by 2022-07-13 00:00:00
# Ticker: DXCM
# Correctly predicted direction of change 75.87006960556845% of the time
# Up 49.651972157772626% of the time
# MSE Loss: 0.4754725651651167
# Standard deviation: actual = 0.9712700749733861, predicted = 0.46271881721792363
# -0.581537716397515 by 2022-07-13 00:00:00
# Ticker: FANG
# Correctly predicted direction of change 72.72727272727273% of the time
# Up 52.47933884297521% of the time
# MSE Loss: 0.5829789384267847
# Standard deviation: actual = 1.045883735833443, predicted = 0.6224106237096707
# 0.17176292578419033 by 2022-07-13 00:00:00
# Ticker: DLR
# Correctly predicted direction of change 71.10609480812641% of the time
# Up 53.04740406320542% of the time
# MSE Loss: 0.7113847052569763
# Standard deviation: actual = 1.0382439511879127, predicted = 0.41495272445141884
# 0.25066632053505133 by 2022-07-13 00:00:00
# Ticker: DFS
# Correctly predicted direction of change 72.67904509283821% of the time
# Up 50.92838196286472% of the time
# MSE Loss: 0.4677193399751342
# Standard deviation: actual = 0.8750255465275556, predicted = 0.3873282626732609
# -0.08029063921200967 by 2022-07-13 00:00:00
# Ticker: DISCA
# Ticker: DISCK
# Ticker: DISH
# Correctly predicted direction of change 76.41843971631207% of the time
# Up 52.4822695035461% of the time
# MSE Loss: 0.5311967257637266
# Standard deviation: actual = 0.9112447134240834, predicted = 0.3732989542528389
# 0.07197586534181573 by 2022-07-13 00:00:00
# Ticker: DG
# Correctly predicted direction of change 73.10126582278481% of the time
# Up 47.78481012658228% of the time
# MSE Loss: 0.8024589181842245
# Standard deviation: actual = 1.0934866161705807, predicted = 0.4336562485653098
# -0.6620834507801544 by 2022-07-13 00:00:00
# Ticker: DLTR
# Correctly predicted direction of change 73.40425531914893% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6552042816336839
# Standard deviation: actual = 0.9890858266019815, predicted = 0.39837108764422363
# 0.18647114858823202 by 2022-07-13 00:00:00
# Ticker: D
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.6298477812846976
# Standard deviation: actual = 0.9797531590163562, predicted = 0.38517885481596714
# -0.4196779859180073 by 2022-07-13 00:00:00
# Ticker: DPZ
# Correctly predicted direction of change 69.77777777777779% of the time
# Up 53.333333333333336% of the time
# MSE Loss: 0.6580117652660809
# Standard deviation: actual = 1.0710721973754553, predicted = 0.48211836082203247
# 0.25192276164582644 by 2022-07-13 00:00:00
# Ticker: DOV
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 50.35460992907801% of the time
# MSE Loss: 0.7647511179309439
# Standard deviation: actual = 1.0273952698633904, predicted = 0.37079634835374303
# 0.20158717692900965 by 2022-07-13 00:00:00
# Ticker: DOW
# Correctly predicted direction of change 76.5432098765432% of the time
# Up 48.148148148148145% of the time
# MSE Loss: 0.46183325270730424
# Standard deviation: actual = 0.9065913832807625, predicted = 0.6450552832111205
# 0.19717322113889307 by 2022-07-13 00:00:00
# Ticker: DTE
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 51.24113475177305% of the time
# MSE Loss: 0.678601187921969
# Standard deviation: actual = 1.0944261642908995, predicted = 0.5218803193650535
# 0.5615128026783939 by 2022-07-13 00:00:00
# Ticker: DUK
# Correctly predicted direction of change 71.27659574468085% of the time
# Up 51.41843971631206% of the time
# MSE Loss: 0.5850482123793711
# Standard deviation: actual = 0.931309586675125, predicted = 0.35106347049287134
# -0.7342493930220122 by 2022-07-13 00:00:00
# Ticker: DRE
# Correctly predicted direction of change 76.06382978723404% of the time
# Up 53.90070921985816% of the time
# MSE Loss: 0.7646276184250019
# Standard deviation: actual = 1.1111574840181706, predicted = 0.4420261634758622
# -0.07048003875168049 by 2022-07-13 00:00:00
# Ticker: DD
# Correctly predicted direction of change 70.0354609929078% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.5208760717887663
# Standard deviation: actual = 0.9738838740922211, predicted = 0.46452837191923424
# 0.22723865161947043 by 2022-07-13 00:00:00
# Ticker: DXC
# Correctly predicted direction of change 74.822695035461% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.5359222502295137
# Standard deviation: actual = 0.9084153307448709, predicted = 0.40752221950496936
# -0.1759233769923602 by 2022-07-13 00:00:00
# Ticker: EMN
# Correctly predicted direction of change 73.40425531914893% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.5629050048536591
# Standard deviation: actual = 0.9933180902518388, predicted = 0.43003880035525477
# -0.3305325551325644 by 2022-07-13 00:00:00
# Ticker: ETN
# Correctly predicted direction of change 75.70921985815603% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.7272518244628715
# Standard deviation: actual = 1.0409227550337472, predicted = 0.3443156952220839
# 0.14185093133761864 by 2022-07-13 00:00:00
# Ticker: EBAY
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 46.27659574468085% of the time
# MSE Loss: 0.6205010083994482
# Standard deviation: actual = 1.001919297267608, predicted = 0.37993642959117924
# -0.1968965237016371 by 2022-07-13 00:00:00
# Ticker: ECL
# Correctly predicted direction of change 70.74468085106383% of the time
# Up 48.93617021276596% of the time
# MSE Loss: 0.7238800476329945
# Standard deviation: actual = 0.9780104542057417, predicted = 0.3534334674559782
# 0.10991918448536162 by 2022-07-13 00:00:00
# Ticker: EIX
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 53.36879432624113% of the time
# MSE Loss: 0.6145997044773533
# Standard deviation: actual = 0.9936442493452627, predicted = 0.40822838025162417
# 0.3068061868466003 by 2022-07-13 00:00:00
# Ticker: EW
# Correctly predicted direction of change 66.30824372759857% of the time
# Up 50.0% of the time
# MSE Loss: 0.7549472311952081
# Standard deviation: actual = 1.0146763426207834, predicted = 0.4348567615456519
# -0.08752940308441634 by 2022-07-13 00:00:00
# Ticker: EA
# Correctly predicted direction of change 67.73049645390071% of the time
# Up 49.46808510638298% of the time
# MSE Loss: 0.8820088154979
# Standard deviation: actual = 1.011208159599155, predicted = 0.28908226429877537
# -0.05297645382551441 by 2022-07-13 00:00:00
# Ticker: LLY
# Correctly predicted direction of change 73.40425531914893% of the time
# Up 52.4822695035461% of the time
# MSE Loss: 0.5405366417077968
# Standard deviation: actual = 0.9502115879836056, predicted = 0.40909068862727127
# 0.15574026261073917 by 2022-07-13 00:00:00
# Ticker: EMR
# Correctly predicted direction of change 68.43971631205675% of the time
# Up 46.98581560283688% of the time
# MSE Loss: 0.8766506424137137
# Standard deviation: actual = 1.0560378107906296, predicted = 0.31098557705568985
# 0.6561320363289735 by 2022-07-13 00:00:00
# Ticker: ENPH
# Correctly predicted direction of change 73.828125% of the time
# Up 50.390625% of the time
# MSE Loss: 0.7258606928971335
# Standard deviation: actual = 1.0569690564733691, predicted = 0.3994569868321826
# -0.20135792987953427 by 2022-07-13 00:00:00
# Ticker: ETR
# Correctly predicted direction of change 69.50354609929079% of the time
# Up 52.4822695035461% of the time
# MSE Loss: 0.5999984640896284
# Standard deviation: actual = 0.9728418348234714, predicted = 0.423521208376137
# 0.5682109259057017 by 2022-07-13 00:00:00
# Ticker: EOG
# Correctly predicted direction of change 75.0% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.6624147212714278
# Standard deviation: actual = 0.9728096724031293, predicted = 0.3832661301396473
# -0.321664393342651 by 2022-07-13 00:00:00
# Ticker: EFX
# Correctly predicted direction of change 75.177304964539% of the time
# Up 54.43262411347518% of the time
# MSE Loss: 0.6537620413268656
# Standard deviation: actual = 1.016606207296445, predicted = 0.41037514356848986
# -0.12926071365583602 by 2022-07-13 00:00:00
# Ticker: EQIX
# Correctly predicted direction of change 66.78832116788321% of the time
# Up 49.45255474452554% of the time
# MSE Loss: 0.4269226193062109
# Standard deviation: actual = 0.8522373223288678, predicted = 0.396508446744897
# -0.19262830791238547 by 2022-07-13 00:00:00
# Ticker: EQR
# Correctly predicted direction of change 72.69503546099291% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.7936371210589251
# Standard deviation: actual = 1.0697175273039474, predicted = 0.4269616230025062
# -0.061337319569983034 by 2022-07-13 00:00:00
# Ticker: ESS
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 51.41843971631206% of the time
# MSE Loss: 0.600014245808397
# Standard deviation: actual = 0.943362182779877, predicted = 0.37844215502797074
# 0.0767664218615153 by 2022-07-13 00:00:00
# Ticker: EL
# Correctly predicted direction of change 69.68085106382979% of the time
# Up 51.95035460992907% of the time
# MSE Loss: 0.6085854538624095
# Standard deviation: actual = 0.9353619488218314, predicted = 0.3544919707805744
# -1.2777565088998275 by 2022-07-13 00:00:00
# Ticker: ETSY
# Correctly predicted direction of change 77.6536312849162% of the time
# Up 43.575418994413404% of the time
# MSE Loss: 0.6676455606941327
# Standard deviation: actual = 1.1022391573799337, predicted = 0.4870077442464703
# -0.22434737522013218 by 2022-07-13 00:00:00
# Ticker: RE
# Correctly predicted direction of change 75.53191489361703% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.697368931631694
# Standard deviation: actual = 1.013026848660518, predicted = 0.42153571617190144
# -0.19583317157792288 by 2022-07-13 00:00:00
# Ticker: EVRG
# Correctly predicted direction of change 72.51773049645391% of the time
# Up 55.49645390070922% of the time
# MSE Loss: 0.5138916967623578
# Standard deviation: actual = 0.8837523813284621, predicted = 0.3860517428133035
# -0.08400763507618653 by 2022-07-13 00:00:00
# Ticker: ES
# Correctly predicted direction of change 68.43971631205675% of the time
# Up 49.822695035460995% of the time
# MSE Loss: 0.7460419011833637
# Standard deviation: actual = 0.9683382990756045, predicted = 0.40196163426566706
# 0.08817890243233262 by 2022-07-13 00:00:00
# Ticker: EXC
# ...
# -0.010350826943789481 by 2022-07-13 00:00:00
# Ticker: GNRC
# Correctly predicted direction of change 76.45161290322581% of the time
# Up 45.483870967741936% of the time
# MSE Loss: 0.5393743730368595
# Standard deviation: actual = 0.9821844571785375, predicted = 0.43741908945393976
# 0.3524834754928606 by 2022-07-13 00:00:00
# Ticker: GD
# Correctly predicted direction of change 68.43971631205675% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6049783865646836
# Standard deviation: actual = 0.9550276668285975, predicted = 0.4123188146668541
# -0.01017550163957043 by 2022-07-13 00:00:00
# Ticker: GE
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 49.29078014184397% of the time
# MSE Loss: 0.6500991353710689
# Standard deviation: actual = 0.9727077420802518, predicted = 0.4099465135555273
# -0.10692900398947082 by 2022-07-13 00:00:00
# Ticker: GIS
# Correctly predicted direction of change 69.32624113475178% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.7203522501852396
# Standard deviation: actual = 1.0064962757603333, predicted = 0.3665759669956294
# -0.16040886495075907 by 2022-07-13 00:00:00
# Ticker: GM
# Correctly predicted direction of change 75.17241379310344% of the time
# Up 48.96551724137931% of the time
# MSE Loss: 0.5592032862641693
# Standard deviation: actual = 1.0022155561486588, predicted = 0.43439051917518556
# 0.41291997968146144 by 2022-07-13 00:00:00
# Ticker: GPC
# Correctly predicted direction of change 70.74468085106383% of the time
# Up 45.744680851063826% of the time
# MSE Loss: 0.5881319426518372
# Standard deviation: actual = 0.9753297350432294, predicted = 0.3856943219938245
# 0.06776909977062127 by 2022-07-13 00:00:00
# Ticker: GILD
# Correctly predicted direction of change 67.73049645390071% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.6282615970971375
# Standard deviation: actual = 0.9653684336999071, predicted = 0.4617155935792711
# -0.07914233003651136 by 2022-07-13 00:00:00
# Ticker: GPN
# Correctly predicted direction of change 67.84386617100373% of the time
# Up 55.20446096654275% of the time
# MSE Loss: 0.7523469245914328
# Standard deviation: actual = 0.9892666651584758, predicted = 0.34688902712961783
# -0.009517799982639095 by 2022-07-13 00:00:00
# Ticker: GL
# Correctly predicted direction of change 68.79432624113475% of the time
# Up 48.93617021276596% of the time
# MSE Loss: 0.6626197102717957
# Standard deviation: actual = 1.0660503887339006, predicted = 0.48386381158721564
# 0.0048307967845254915 by 2022-07-13 00:00:00
# Ticker: GS
# Correctly predicted direction of change 74.29078014184397% of the time
# Up 53.01418439716312% of the time
# MSE Loss: 0.824468418785491
# Standard deviation: actual = 1.0702135791801506, predicted = 0.3701470268864584
# 0.10099009037621999 by 2022-07-13 00:00:00
# Ticker: HAL
# Correctly predicted direction of change 71.27659574468085% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.6282604025338107
# Standard deviation: actual = 1.0410611247887442, predicted = 0.5161075669365722
# 0.5330249918891682 by 2022-07-13 00:00:00
# Ticker: HBI
# Correctly predicted direction of change 71.71717171717171% of the time
# Up 55.05050505050505% of the time
# MSE Loss: 0.5364019370774902
# Standard deviation: actual = 0.9547222151835795, predicted = 0.4496527491252944
# 0.3037758705840972 by 2022-07-13 00:00:00
# Ticker: HAS
# Correctly predicted direction of change 76.77304964539007% of the time
# Up 49.11347517730496% of the time
# MSE Loss: 0.5815024537657181
# Standard deviation: actual = 1.0476927124638507, predicted = 0.5211838528117182
# -0.07030218553919058 by 2022-07-13 00:00:00
# Ticker: HCA
# Correctly predicted direction of change 74.822695035461% of the time
# Up 51.06382978723404% of the time
# MSE Loss: 0.6171437657716359
# Standard deviation: actual = 1.0090147215089469, predicted = 0.44158573742482254
# -0.15752974141621606 by 2022-07-13 00:00:00
# Ticker: PEAK
# Correctly predicted direction of change 76.24113475177306% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6174412583279036
# Standard deviation: actual = 0.9718581001973896, predicted = 0.4205332882633256
# 0.016895273786640685 by 2022-07-13 00:00:00
# Ticker: HSIC
# Correctly predicted direction of change 71.80851063829788% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6577613959570422
# Standard deviation: actual = 1.031211813813555, predicted = 0.45446346610785726
# 0.15871897220574696 by 2022-07-13 00:00:00
# Ticker: HES
# Correctly predicted direction of change 76.77304964539007% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.5872309978166705
# Standard deviation: actual = 1.0119916554137998, predicted = 0.4598479698275946
# 0.38480415828280157 by 2022-07-13 00:00:00
# Ticker: HPE
# Correctly predicted direction of change 74.69879518072288% of the time
# Up 56.62650602409639% of the time
# MSE Loss: 0.4966380205779545
# Standard deviation: actual = 0.9656556877924899, predicted = 0.5728599729862546
# 0.4483874715185801 by 2022-07-13 00:00:00
# Ticker: HLT
# Correctly predicted direction of change 67.13615023474179% of the time
# Up 50.23474178403756% of the time
# MSE Loss: 0.580917123259364
# Standard deviation: actual = 0.9345817361892473, predicted = 0.46952001312094427
# 0.2933121571948181 by 2022-07-13 00:00:00
# Ticker: HOLX
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 48.93617021276596% of the time
# MSE Loss: 0.6444373766594235
# Standard deviation: actual = 1.0079624627462667, predicted = 0.4735165077809368
# -0.27227608320798996 by 2022-07-13 00:00:00
# Ticker: HD
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.6916830416431641
# Standard deviation: actual = 0.9907328790475715, predicted = 0.41002956265711116
# -0.07529642515741355 by 2022-07-13 00:00:00
# Ticker: HON
# Correctly predicted direction of change 71.27659574468085% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.6404089038207516
# Standard deviation: actual = 0.9642121308838418, predicted = 0.34993913210181465
# 0.19426270910150226 by 2022-07-13 00:00:00
# Ticker: HRL
# Correctly predicted direction of change 72.87234042553192% of the time
# Up 46.27659574468085% of the time
# MSE Loss: 0.8244663300139409
# Standard deviation: actual = 1.0530441806433835, predicted = 0.3371346940269628
# 0.46726757329316854 by 2022-07-13 00:00:00
# Ticker: HST
# Correctly predicted direction of change 76.06382978723404% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.5805887311695005
# Standard deviation: actual = 0.9922547961780614, predicted = 0.5103466050029815
# 0.22177563669665265 by 2022-07-13 00:00:00
# Ticker: HWM
# Correctly predicted direction of change 71.42857142857143% of the time
# Up 56.42857142857143% of the time
# MSE Loss: 0.5477639541305306
# Standard deviation: actual = 0.9900110422299755, predicted = 0.6287925279636215
# -0.7686353624665143 by 2022-07-13 00:00:00
# Ticker: HPQ
# Correctly predicted direction of change 71.09929078014184% of the time
# Up 49.822695035460995% of the time
# MSE Loss: 0.6800061150435963
# Standard deviation: actual = 0.954559476409991, predicted = 0.3208522618764078
# 0.6205990957023437 by 2022-07-13 00:00:00
# Ticker: HUM
# Correctly predicted direction of change 74.11347517730496% of the time
# Up 50.177304964539005% of the time
# MSE Loss: 0.5091633192955568
# Standard deviation: actual = 0.961321412982241, predicted = 0.40719322044926665
# -0.24900123332034357 by 2022-07-13 00:00:00
# Ticker: HBAN
# Correctly predicted direction of change 71.27659574468085% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.6553813935362329
# Standard deviation: actual = 1.0398643865701347, predicted = 0.48032364869498106
# 0.04698079452175274 by 2022-07-13 00:00:00
# Ticker: HII
# Correctly predicted direction of change 73.04964539007092% of the time
# Up 45.744680851063826% of the time
# MSE Loss: 0.5215940988588756
# Standard deviation: actual = 0.9362939021578536, predicted = 0.4063047048501461
# -0.04929651154082434 by 2022-07-13 00:00:00
# Ticker: IBM
# Correctly predicted direction of change 72.87234042553192% of the time
# Up 48.226950354609926% of the time
# MSE Loss: 0.5852340214776275
# Standard deviation: actual = 0.9943081600457717, predicted = 0.46327116590800715
# 0.1774461390033098 by 2022-07-13 00:00:00
# Ticker: IEX
# Correctly predicted direction of change 71.80851063829788% of the time
# Up 52.304964539007095% of the time
# MSE Loss: 0.6654097308012341
# Standard deviation: actual = 0.9665349218128091, predicted = 0.35636083512981204
# 0.17964523829531603 by 2022-07-13 00:00:00
# Ticker: IDXX
# Correctly predicted direction of change 70.56737588652481% of the time
# Up 50.88652482269504% of the time
# MSE Loss: 0.6839041614608719
# Standard deviation: actual = 1.0335617700530186, predicted = 0.49993079896612297
# 0.057005419649354225 by 2022-07-13 00:00:00
# Ticker: INFO
# Ticker: ITW
# Correctly predicted direction of change 66.66666666666666% of the time
# Up 51.41843971631206% of the time
# MSE Loss: 0.7153582630563735
# Standard deviation: actual = 0.9646207751763215, predicted = 0.3816714346329712
# 0.07954254363772573 by 2022-07-13 00:00:00
# Ticker: ILMN
# Correctly predicted direction of change 72.85974499089252% of the time
# Up 54.462659380692166% of the time
# MSE Loss: 0.6912523475947141
# Standard deviation: actual = 1.116556188547087, predicted = 0.47338452804478254
# -0.10179235143766836 by 2022-07-13 00:00:00
# Ticker: INCY
# Correctly predicted direction of change 72.3404255319149% of the time
# Up 51.59574468085106% of the time
# MSE Loss: 0.7132953825441877
# Standard deviation: actual = 1.0971367908891583, predicted = 0.4724931443290786
# -0.47450599785811676 by 2022-07-13 00:00:00
# Ticker: IR
# Correctly predicted direction of change 74.01574803149606% of the time
# Up 48.818897637795274% of the time
# MSE Loss: 0.3474822668664054
# Standard deviation: actual = 0.8532443617465271, predicted = 0.5036130444791332
# 0.2646088868635689 by 2022-07-13 00:00:00
# Ticker: INTC
# Correctly predicted direction of change 71.80851063829788% of the time
# Up 51.77304964539007% of the time
# MSE Loss: 0.6924842698603124
# Standard deviation: actual = 1.0245627771559667, predicted = 0.37572872742271957
# 0.9548350021881421 by 2022-07-13 00:00:00
# Ticker: ICE
# Correctly predicted direction of change 70.1923076923077% of the time
# Up 47.355769230769226% of the time
# MSE Loss: 0.6336173748253038
# Standard deviation: actual = 0.9752239410252375, predicted = 0.43170446990493616
# -0.09672249740373795 by 2022-07-13 00:00:00
# Ticker: IFF
# Correctly predicted direction of change 73.04964539007092% of the time
# Up 48.58156028368794% of the time
# MSE Loss: 0.5747095449759382
# Standard deviation: actual = 0.95655429536972, predicted = 0.37320684055947506
# -0.23663737858041295 by 2022-07-13 00:00:00
# Ticker: IP
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 50.177304964539005% of the time
# MSE Loss: 0.5648040861943524
# Standard deviation: actual = 0.9665453950154779, predicted = 0.4531838726885092
# 0.3429794494488854 by 2022-07-13 00:00:00
# Ticker: IPG
# Correctly predicted direction of change 73.22695035460993% of the time
# Up 47.87234042553192% of the time
# MSE Loss: 0.5842950596100729
# Standard deviation: actual = 1.0062494284857613, predicted = 0.44552103516461367
# -0.31753233798579755 by 2022-07-13 00:00:00
# Ticker: INTU
# Correctly predicted direction of change 72.16312056737588% of the time
# Up 50.70921985815603% of the time
# MSE Loss: 0.5989954360377948
# Standard deviation: actual = 0.9355258030404867, predicted = 0.44619251730776954
# 0.13525612847301954 by 2022-07-13 00:00:00
# Ticker: ISRG
# Correctly predicted direction of change 79.16666666666666% of the time
# Up 49.275362318840585% of the time
# MSE Loss: 0.511621864981634
# Standard deviation: actual = 0.9268214409547897, predicted = 0.4111208127298376
# -0.6716402576329921 by 2022-07-13 00:00:00
# Ticker: IVZ
# Correctly predicted direction of change 73.04964539007092% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.5346079317462852
# Standard deviation: actual = 0.9364757167283749, predicted = 0.43412462401883734
# -0.7039653633698331 by 2022-07-13 00:00:00
# Ticker: IPGP
# Correctly predicted direction of change 78.1491002570694% of the time
# Up 53.98457583547558% of the time
# MSE Loss: 0.6243860277086097
# Standard deviation: actual = 0.9659128695349907, predicted = 0.35531569429811144
# -0.19568449942154903 by 2022-07-13 00:00:00
# Ticker: IQV
# Correctly predicted direction of change 72.36842105263158% of the time
# Up 49.122807017543856% of the time
# MSE Loss: 0.5325630529007873
# Standard deviation: actual = 0.9717430478870619, predicted = 0.47194513426377865
# 0.10197108306143537 by 2022-07-13 00:00:00
# Ticker: IRM
# Correctly predicted direction of change 74.822695035461% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.5468183995713992
# Standard deviation: actual = 0.951460670181925, predicted = 0.4155094821483223
# -0.1758942805089436 by 2022-07-13 00:00:00
# Ticker: JBHT
# Correctly predicted direction of change 69.68085106382979% of the time
# Up 47.87234042553192% of the time
# MSE Loss: 0.6162678593090559
# Standard deviation: actual = 0.9754568137198625, predicted = 0.4162048865813189
# 0.5225361146580743 by 2022-07-13 00:00:00
# Ticker: JKHY
# Correctly predicted direction of change 74.46808510638297% of the time
# Up 51.06382978723404% of the time
# MSE Loss: 0.757983677556172
# Standard deviation: actual = 1.0470768384792275, predicted = 0.4118169206543285
# -0.7792430955386708 by 2022-07-13 00:00:00
# Ticker: J
# Correctly predicted direction of change 72.69503546099291% of the time
# Up 50.35460992907801% of the time
# MSE Loss: 0.7409268801700255
# Standard deviation: actual = 1.1401187149436638, predicted = 0.4458317390400574
# -1.1324381482351908 by 2022-07-13 00:00:00
# Ticker: SJM
# Correctly predicted direction of change 69.14893617021278% of the time
# Up 54.96453900709219% of the time
# MSE Loss: 0.8040349853463051
# Standard deviation: actual = 1.0564596816796117, predicted = 0.37167642658047517
# 0.1707088556696256 by 2022-07-13 00:00:00
# Ticker: JNJ
# Correctly predicted direction of change 74.822695035461% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.6437253816067113
# Standard deviation: actual = 0.9905373660237393, predicted = 0.4404750340711141
# 0.3619565937566962 by 2022-07-13 00:00:00
# Ticker: JCI
# Correctly predicted direction of change 73.93617021276596% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.6073884268161311
# Standard deviation: actual = 0.9765659543542646, predicted = 0.426303653001184
# -0.7448761640646444 by 2022-07-13 00:00:00
# Ticker: JPM
# Correctly predicted direction of change 73.58156028368793% of the time
# Up 51.95035460992907% of the time
# MSE Loss: 0.5795561798281436
# Standard deviation: actual = 0.9720098653116331, predicted = 0.44269094189148384
# 0.047540913860635484 by 2022-07-13 00:00:00
# Ticker: JNPR
# Correctly predicted direction of change 75.53191489361703% of the time
# Up 50.0% of the time
# MSE Loss: 0.5962206326713786
# Standard deviation: actual = 0.9822308128276104, predicted = 0.42109996028450086
# 0.5366078617132388 by 2022-07-13 00:00:00
# Ticker: KSU
# Ticker: K
# Correctly predicted direction of change 69.50354609929079% of the time
# Up 50.53191489361703% of the time
# MSE Loss: 0.7193617016616972
# Standard deviation: actual = 1.013617211415594, predicted = 0.40256547548920796
# 0.04302206988155504 by 2022-07-13 00:00:00
# Ticker: KEY
# Correctly predicted direction of change 71.80851063829788% of the time
# Up 49.645390070921984% of the time
# MSE Loss: 0.9157327353053606
# Standard deviation: actual = 1.1681435571677432, predicted = 0.4819139666708604
# -0.6383937947800373 by 2022-07-13 00:00:00
# Ticker: KEYS
# Correctly predicted direction of change 69.27083333333334% of the time
# Up 46.35416666666667% of the time
# MSE Loss: 0.5247189227228491
# Standard deviation: actual = 0.9982977859973837, predicted = 0.5289242722728372
# -0.3775033889137173 by 2022-07-13 00:00:00
# Ticker: KMB
# Correctly predicted direction of change 75.35460992907801% of the time
# Up 52.12765957446809% of the time
# MSE Loss: 0.6022010463565022
# Standard deviation: actual = 0.9399851192745863, predicted = 0.4220236092825241
# 0.3119023978564839 by 2022-07-13 00:00:00
# Ticker: KIM

# %%
print('Mean:', np.mean(list(predictions.values())))

df = pd.DataFrame()
df['symbol'] = predictions.keys()
df['prediction'] = predictions.values()
df.to_csv('5-day-predictions-made_on_13-07-22.csv')
df

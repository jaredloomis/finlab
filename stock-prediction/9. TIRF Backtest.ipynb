# %%
# Auto reload local files
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# Make files in src/ available to notebook
import sys
if 'src' not in sys.path:
    sys.path.insert(0, 'src')

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV

from technical_signals import TechnicalSignals, percent_change
import datastore as ds
import backtest as bt
from strategy import TechnicalIndicatorsModelStrategy, DummyStrategy

# XXX NOTE VERY IMPORTANT
# THIS FILTERS ALL WARNINGS - ta library is giving annoying warnings.
# REMOVE AND RESTART before modifying any bt code
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 10]

spy_constituents = list(pd.read_csv('../../data/spy_constituents.csv', header=0)['Symbol'])
random.shuffle(spy_constituents)

tickers = spy_constituents[:2]

strategies = [
    #('Grid search SVR', TechnicalIndicatorsModelStrategy(svr_grid, window=7, cutoff=0.5, bias=0.1)),
    ('MLP', TechnicalIndicatorsModelStrategy(MLPRegressor(), window=14, cutoff=2, bias=0.1)),
    ('Random Forest', TechnicalIndicatorsModelStrategy(RandomForestRegressor(n_jobs=-1, criterion='absolute_error'), window=14, cutoff=1.5, bias=0.4)),
    ('SGD', TechnicalIndicatorsModelStrategy(SGDRegressor(), window=14, cutoff=2, bias=0.1)),
    ('SVR', TechnicalIndicatorsModelStrategy(SVR(), window=14, cutoff=2, bias=0.1)),
]

"""
for name, strategy in strategies:
    print(f"========== TESTING MODEL: {name} ===========\n\n")
    bt_summary = bt.comprehensive_backtest(strategy, tickers, plot=True, skip_index=252*15, processes=8)
    print(bt_summary)
"""

for name, strategy in strategies:
    print(f"========== TESTING MODEL: {name} ===========\n\n")
    bt_summary = bt.comprehensive_backtest(strategy, tickers, "2000-01-01", "2023-06-06", plot=True, train_test_ratio=0.95, processes=8)
    print(bt_summary)
#strategy = DummyStrategy()
#dummy_summary = bt.comprehensive_backtest(strategy, tickers, plot=True, skip_index=252*15, processes=8)
#print(dummy_summary)
# Out:
# ========== TESTING MODEL: MLP ===========
#
#
# Ticker: PNC
# 23 buy/sells performed - 0.40421792618629176% of the time
# Stock price change: -8.856994091918114%
# Total gain/loss: -0.5784985351562499%
# {'cash': 6304.450012207031, 'assets': 22, 'latest_price': 165.35000610351562, 'total_value': 9942.150146484375}
# Ticker: TSCO
# 62 buy/sells performed - 1.0896309314586996% of the time
# Stock price change: 7.348049033406228%
# Total gain/loss: -0.7721026611328125%
# {'cash': 567.5900268554688, 'assets': 48, 'latest_price': 194.89999389648438, 'total_value': 9922.789733886719}
# {'average_gainloss': -67.53005981445312, 'results': {'PNC': {'cash': 6304.450012207031, 'assets': 22, 'latest_price': 165.35000610351562, 'total_value': 9942.150146484375}, 'TSCO': {'cash': 567.5900268554688, 'assets': 48, 'latest_price': 194.89999389648438, 'total_value': 9922.789733886719}}}
# ========== TESTING MODEL: Random Forest ===========
#
#
# Ticker: PNC
# feature importance:
# pchange_-480day: 0.03855860611488006
# pchange_-1920day: 0.03178245314326462
# donchian40_wband: 0.031285341148195984
# pchange_-240day: 0.030226255491021
# ulcer40: 0.029912834478033043
# donchian20_wband: 0.027759904950420213
# ulcer120: 0.02771764861073955
# pchange_-960day: 0.026589400114019775
# kama240: 0.026041858440461127
# ulcer80: 0.025735170448405658
# pchange_-60day: 0.02424707062168767
# avg_true_range: 0.024223203640436845
# avg_true_range120: 0.023792973347706244
# avg_true_range60: 0.023672243083475247
# kst_sig: 0.021939555080332736
# bollinger_wband: 0.02186764275502495
# pchange_-120day: 0.021578235878991544
# ema120: 0.020734290945989334
# donchian20_mband: 0.020629717669338795
# kst_diff: 0.01959011605413165
# ema30: 0.018247420820961587
# ulcer14: 0.018029970322299752
# macd_diff: 0.01801694255866942
# rsi240: 0.015747009102238085
# pchange_-3day: 0.014466435013186238
# aroon_indicator: 0.014449962203986455
# adx: 0.01406445309707652
# macd_signal: 0.0140220563940724
# adx30: 0.01396533648118709
# pchange_-7day: 0.01384059580593078
# pchange_-14day: 0.01374067150316187
# pchange_-4day: 0.013700045339815002
# kama60: 0.013450605518091054
# pchange_-1day: 0.013332513170901632
# kama120: 0.013137634859970222
# pchange_-2day: 0.012827937628104002
# rsi120: 0.012708347964803832
# pchange_-30day: 0.012675003167075309
# donchian40_mband: 0.012439425529279714
# cci: 0.012416064552833839
# pchange_-5day: 0.012197282878628903
# macd: 0.012058790984844147
# close: 0.011630398503464407
# donchian40_pband: 0.011399262606766755
# kst: 0.011377853276498323
# adx_neg30: 0.011363391459488574
# adx_neg: 0.011169288471770877
# kama: 0.011079312187604086
# ema60: 0.010643552641010069
# rsi30: 0.010575534023052946
# ema14: 0.010178094156345623
# donchian20_pband: 0.010082553953708044
# rsi60: 0.010077990480527241
# rsi14: 0.009968885170341798
# percent_price_osc: 0.008961798383610471
# aroon_up: 0.008679042753277305
# adx_pos30: 0.008667237257102823
# aroon_down: 0.008533261644538416
# adx_pos: 0.008193516117218263
# 0 buy/sells performed - 0.0% of the time
# Stock price change: -8.856994091918114%
# Total gain/loss: 0%
# None
# Ticker: TSCO
# feature importance:
# pchange_-1920day: 0.05984295765788066
# donchian40_wband: 0.04592539850911624
# kama: 0.04434816427636634
# ulcer120: 0.035791530464855885
# pchange_-480day: 0.03190828629844254
# pchange_-240day: 0.030150235880363113
# pchange_-960day: 0.029049969677321735
# ulcer40: 0.02767218537300663
# pchange_-60day: 0.026918375633000164
# avg_true_range: 0.025970062294588946
# ulcer80: 0.025821110395477
# pchange_-120day: 0.023791827237700455
# kst_sig: 0.021770121233425376
# avg_true_range60: 0.021650493136197504
# rsi120: 0.020009641840368745
# avg_true_range120: 0.01969390493742735
# donchian20_wband: 0.01968251855211445
# kama240: 0.0194173086220284
# ema120: 0.017735051473351453
# rsi240: 0.017691054623784966
# ulcer14: 0.017046939993433305
# macd_signal: 0.01680430050969066
# kst_diff: 0.016417008240680417
# bollinger_wband: 0.015372766965499423
# adx: 0.015323695426090722
# adx30: 0.01501318638574893
# macd_diff: 0.014705132280539828
# kst: 0.014334103938299134
# pchange_-30day: 0.013997449018977171
# close: 0.01315449368156054
# percent_price_osc: 0.013109725051731145
# kama120: 0.012584850683499285
# rsi60: 0.012147462857533597
# kama60: 0.011504320346537047
# macd: 0.011079564203913988
# cci: 0.010870770696864351
# pchange_-7day: 0.010773634154959
# ema14: 0.010721450387608926
# pchange_-5day: 0.010559658067608406
# pchange_-2day: 0.010504999857382027
# rsi14: 0.010317493917856649
# pchange_-14day: 0.010280237710896896
# donchian40_pband: 0.010274762659158523
# pchange_-1day: 0.010147531873387343
# pchange_-3day: 0.010122234491198147
# pchange_-4day: 0.009722978086110463
# rsi30: 0.00919902874882902
# donchian20_pband: 0.008821270853187629
# ema30: 0.00879615730813966
# adx_pos30: 0.008705125633826444
# aroon_indicator: 0.008588344657514789
# adx_neg30: 0.008573746113487076
# aroon_up: 0.008453878638689896
# adx_pos: 0.008314540983351517
# adx_neg: 0.008235453220608806
# ema60: 0.007968986772080877
# aroon_down: 0.007943800862298697
# donchian20_mband: 0.007822478628379282
# donchian40_mband: 0.006846237976022352
# 1 buy/sells performed - 0.01757469244288225% of the time
# Stock price change: 7.348049033406228%
# Total gain/loss: 0.0%
# {'cash': 9804.440002441406, 'assets': 1, 'latest_price': 195.55999755859375, 'total_value': 10000.0}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 57>()
#      57 for name, strategy in strategies:
#      58     print(f"========== TESTING MODEL: {name} ===========\n\n")
# ---> 59     bt_summary = bt.comprehensive_backtest(strategy, tickers, "2000-01-01", "2023-06-06", plot=True, train_test_ratio=0.95, processes=8)
#      60     print(bt_summary)
#
# File ~/workspace/market-diff/notebooks/stock-prediction/src/backtest.py:60, in comprehensive_backtest(strategy, tickers, start_date, end_date, start_cash, train_test_ratio, plot, log, **kwargs)
#      57         traceback.print_exception(type(ex), ex, ex.__traceback__)
#      59 # Summarize results
# ---> 60 gainloss_summary = list(map(lambda res: res["total_value"] - start_cash, results.values()))
#      61 if len(gainloss_summary) > 0:
#      62     average_gainloss = sum(gainloss_summary) / len(gainloss_summary)
#
# File ~/workspace/market-diff/notebooks/stock-prediction/src/backtest.py:60, in comprehensive_backtest.<locals>.<lambda>(res)
#      57         traceback.print_exception(type(ex), ex, ex.__traceback__)
#      59 # Summarize results
# ---> 60 gainloss_summary = list(map(lambda res: res["total_value"] - start_cash, results.values()))
#      61 if len(gainloss_summary) > 0:
#      62     average_gainloss = sum(gainloss_summary) / len(gainloss_summary)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
ds.get_daily_candlesticks(['AUD/USD'], '1990-01-01', '2030-01-01')
# Out:
# {'AUD/USD': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
financials = ds.get_financials_reported(["wasabi"])

# %%
financials["wasabi"].head().iloc[0].data
# Out:
# [{'accessNumber': '0000320193-22-000070',
#   'symbol': 'AAPL',
#   'cik': '320193',
#   'year': 2022,
#   'quarter': 3,
#   'form': '10-Q',
#   'startDate': '2021-09-26 00:00:00',
#   'endDate': '2022-06-25 00:00:00',
#   'filedDate': '2022-07-29 00:00:00',
#   'acceptedDate': '2022-07-28 18:06:56',
#   'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue',
#      'unit': 'usd',
#      'label': 'Cash and cash equivalents',
#      'value': 27502000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesCurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 20729000000.0},
#     {'concept': 'us-gaap_AccountsReceivableNetCurrent',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': 21803000000.0},
#     {'concept': 'us-gaap_InventoryNet',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': 5433000000.0},
#     {'concept': 'us-gaap_NontradeReceivablesCurrent',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': 20439000000.0},
#     {'concept': 'us-gaap_OtherAssetsCurrent',
#      'unit': 'usd',
#      'label': 'Other current assets',
#      'value': 16386000000.0},
#     {'concept': 'us-gaap_AssetsCurrent',
#      'unit': 'usd',
#      'label': 'Total current assets',
#      'value': 112292000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 131077000000.0},
#     {'concept': 'us-gaap_PropertyPlantAndEquipmentNet',
#      'unit': 'usd',
#      'label': 'Property, plant and equipment, net',
#      'value': 40335000000.0},
#     {'concept': 'us-gaap_OtherAssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current assets',
#      'value': 52605000000.0},
#     {'concept': 'us-gaap_AssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current assets',
#      'value': 224017000000.0},
#     {'concept': 'us-gaap_Assets',
#      'unit': 'usd',
#      'label': 'Total assets',
#      'value': 336309000000.0},
#     {'concept': 'us-gaap_AccountsPayableCurrent',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': 48343000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Other current liabilities',
#      'value': 48811000000.0},
#     {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 7728000000.0},
#     {'concept': 'us-gaap_CommercialPaper',
#      'unit': 'usd',
#      'label': 'Commercial paper',
#      'value': 10982000000.0},
#     {'concept': 'us-gaap_LongTermDebtCurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 14009000000.0},
#     {'concept': 'us-gaap_LiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Total current liabilities',
#      'value': 129873000000.0},
#     {'concept': 'us-gaap_LongTermDebtNoncurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 94700000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current liabilities',
#      'value': 53629000000.0},
#     {'concept': 'us-gaap_LiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current liabilities',
#      'value': 148329000000.0},
#     {'concept': 'us-gaap_Liabilities',
#      'unit': 'usd',
#      'label': 'Total liabilities',
#      'value': 278202000000.0},
#     {'concept': 'us-gaap_CommonStocksIncludingAdditionalPaidInCapital',
#      'unit': 'usd',
#      'label': 'Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 16,095,378 and 16,426,786 shares issued and outstanding, respectively',
#      'value': 62115000000.0},
#     {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit',
#      'unit': 'usd',
#      'label': 'Retained earnings',
#      'value': 5289000000.0},
#     {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax',
#      'unit': 'usd',
#      'label': 'Accumulated other comprehensive income/(loss)',
#      'value': -9297000000.0},
#     {'concept': 'us-gaap_StockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total shareholders’ equity',
#      'value': 58107000000.0},
#     {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total liabilities and shareholders’ equity',
#      'value': 336309000000.0}],
#    'ic': [{'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax',
#      'unit': 'usd',
#      'label': 'Net sales',
#      'value': 304182000000.0},
#     {'concept': 'us-gaap_CostOfGoodsAndServicesSold',
#      'unit': 'usd',
#      'label': 'Cost of sales',
#      'value': 171495000000.0},
#     {'concept': 'us-gaap_GrossProfit',
#      'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 132687000000.0},
#     {'concept': 'us-gaap_ResearchAndDevelopmentExpense',
#      'unit': 'usd',
#      'label': 'Research and development',
#      'value': 19490000000.0},
#     {'concept': 'us-gaap_SellingGeneralAndAdministrativeExpense',
#      'unit': 'usd',
#      'label': 'Selling, general and administrative',
#      'value': 18654000000.0},
#     {'concept': 'us-gaap_OperatingExpenses',
#      'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 38144000000.0},
#     {'concept': 'us-gaap_OperatingIncomeLoss',
#      'unit': 'usd',
#      'label': 'Operating income',
#      'value': 94543000000.0},
#     {'concept': 'us-gaap_NonoperatingIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other income/(expense), net',
#      'value': -97000000.0},
#     {'concept': 'us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#      'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 94446000000.0},
#     {'concept': 'us-gaap_IncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 15364000000.0},
#     {'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 79082000000.0},
#     {'concept': 'us-gaap_EarningsPerShareBasic',
#      'unit': 'usd/share',
#      'label': 'Basic (in dollars per share)',
#      'value': 4.86},
#     {'concept': 'us-gaap_EarningsPerShareDiluted',
#      'unit': 'usd/share',
#      'label': 'Diluted (in dollars per share)',
#      'value': 4.82},
#     {'concept': 'us-gaap_WeightedAverageNumberOfSharesOutstandingBasic',
#      'unit': 'shares',
#      'label': 'Basic (in shares)',
#      'value': 16277824000.0},
#     {'concept': 'us-gaap_WeightedAverageNumberOfDilutedSharesOutstanding',
#      'unit': 'shares',
#      'label': 'Diluted (in shares)',
#      'value': 16394937000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in foreign currency translation, net of tax',
#      'value': -1102000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossbeforeReclassificationafterTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of derivative instruments',
#      'value': 1548000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossReclassificationAfterTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': 87000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossafterReclassificationandTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on derivative instruments',
#      'value': 1461000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of marketable debt securities',
#      'value': -9959000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': -140000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on marketable debt securities',
#      'value': -9819000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent',
#      'unit': 'usd',
#      'label': 'Total other comprehensive income/(loss)',
#      'value': -9460000000.0},
#     {'concept': 'us-gaap_ComprehensiveIncomeNetOfTax',
#      'unit': 'usd',
#      'label': 'Total comprehensive income',
#      'value': 69622000000.0}],
#    'cf': [{'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 79082000000.0},
#     {'concept': 'us-gaap_DepreciationDepletionAndAmortization',
#      'unit': 'usd',
#      'label': 'Depreciation and amortization',
#      'value': 8239000000.0},
#     {'concept': 'us-gaap_ShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Share-based compensation expense',
#      'value': 6760000000.0},
#     {'concept': 'us-gaap_DeferredIncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Deferred income tax expense/(benefit)',
#      'value': 2756000000.0},
#     {'concept': 'us-gaap_OtherNoncashIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': 61000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsReceivable',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': -4561000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInInventories',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': -1049000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherReceivables',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': -4789000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingAssets',
#      'unit': 'usd',
#      'label': 'Other current and non-current assets',
#      'value': 3289000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsPayable',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': -6108000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInContractWithCustomerLiability',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 260000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingLiabilities',
#      'unit': 'usd',
#      'label': 'Other current and non-current liabilities',
#      'value': -14000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInOperatingActivities',
#      'unit': 'usd',
#      'label': 'Cash generated by operating activities',
#      'value': 98024000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Purchases of marketable securities',
#      'value': 70178000000.0},
#     {'concept': 'us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities',
#      'unit': 'usd',
#      'label': 'Proceeds from maturities of marketable securities',
#      'value': 24203000000.0},
#     {'concept': 'us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Proceeds from sales of marketable securities',
#      'value': 33609000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquirePropertyPlantAndEquipment',
#      'unit': 'usd',
#      'label': 'Payments for acquisition of property, plant and equipment',
#      'value': 7419000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquireBusinessesNetOfCashAcquired',
#      'unit': 'usd',
#      'label': 'Payments made in connection with business acquisitions, net',
#      'value': 169000000.0},
#     {'concept': 'us-gaap_PaymentsForProceedsFromOtherInvestingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': 1183000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInInvestingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in investing activities',
#      'value': -21137000000.0},
#     {'concept': 'us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Payments for taxes related to net share settlement of equity awards',
#      'value': 5915000000.0},
#     {'concept': 'us-gaap_PaymentsOfDividends',
#      'unit': 'usd',
#      'label': 'Payments for dividends and dividend equivalents',
#      'value': 11138000000.0},
#     {'concept': 'us-gaap_PaymentsForRepurchaseOfCommonStock',
#      'unit': 'usd',
#      'label': 'Repurchases of common stock',
#      'value': 64974000000.0},
#     {'concept': 'us-gaap_ProceedsFromIssuanceOfLongTermDebt',
#      'unit': 'usd',
#      'label': 'Proceeds from issuance of term debt, net',
#      'value': 0.0},
#     {'concept': 'us-gaap_RepaymentsOfLongTermDebt',
#      'unit': 'usd',
#      'label': 'Repayments of term debt',
#      'value': 6750000000.0},
#     {'concept': 'us-gaap_ProceedsFromRepaymentsOfCommercialPaper',
#      'unit': 'usd',
#      'label': 'Proceeds from commercial paper, net',
#      'value': 4970000000.0},
#     {'concept': 'us-gaap_ProceedsFromPaymentsForOtherFinancingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': -148000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInFinancingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in financing activities',
#      'value': -83955000000.0},
#     {'concept': 'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect',
#      'unit': 'usd',
#      'label': 'Decrease in cash, cash equivalents and restricted cash',
#      'value': -7068000000.0},
#     {'concept': 'us-gaap_IncomeTaxesPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for income taxes, net',
#      'value': 12251000000.0},
#     {'concept': 'us-gaap_InterestPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for interest',
#      'value': 1910000000.0}]}},
#  {'accessNumber': '0000320193-22-000059',
#   'symbol': 'AAPL',
#   'cik': '320193',
#   'year': 2022,
#   'quarter': 2,
#   'form': '10-Q',
#   'startDate': '2021-09-26 00:00:00',
#   'endDate': '2022-03-26 00:00:00',
#   'filedDate': '2022-04-29 00:00:00',
#   'acceptedDate': '2022-04-28 18:03:58',
#   'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue',
#      'unit': 'usd',
#      'label': 'Cash and cash equivalents',
#      'value': 28098000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesCurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 23413000000.0},
#     {'concept': 'us-gaap_AccountsReceivableNetCurrent',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': 20815000000.0},
#     {'concept': 'us-gaap_InventoryNet',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': 5460000000.0},
#     {'concept': 'us-gaap_NontradeReceivablesCurrent',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': 24585000000.0},
#     {'concept': 'us-gaap_OtherAssetsCurrent',
#      'unit': 'usd',
#      'label': 'Other current assets',
#      'value': 15809000000.0},
#     {'concept': 'us-gaap_AssetsCurrent',
#      'unit': 'usd',
#      'label': 'Total current assets',
#      'value': 118180000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 141219000000.0},
#     {'concept': 'us-gaap_PropertyPlantAndEquipmentNet',
#      'unit': 'usd',
#      'label': 'Property, plant and equipment, net',
#      'value': 39304000000.0},
#     {'concept': 'us-gaap_OtherAssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current assets',
#      'value': 51959000000.0},
#     {'concept': 'us-gaap_AssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current assets',
#      'value': 232482000000.0},
#     {'concept': 'us-gaap_Assets',
#      'unit': 'usd',
#      'label': 'Total assets',
#      'value': 350662000000.0},
#     {'concept': 'us-gaap_AccountsPayableCurrent',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': 52682000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Other current liabilities',
#      'value': 50248000000.0},
#     {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 7920000000.0},
#     {'concept': 'us-gaap_CommercialPaper',
#      'unit': 'usd',
#      'label': 'Commercial paper',
#      'value': 6999000000.0},
#     {'concept': 'us-gaap_LongTermDebtCurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 9659000000.0},
#     {'concept': 'us-gaap_LiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Total current liabilities',
#      'value': 127508000000.0},
#     {'concept': 'us-gaap_LongTermDebtNoncurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 103323000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current liabilities',
#      'value': 52432000000.0},
#     {'concept': 'us-gaap_LiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current liabilities',
#      'value': 155755000000.0},
#     {'concept': 'us-gaap_Liabilities',
#      'unit': 'usd',
#      'label': 'Total liabilities',
#      'value': 283263000000.0},
#     {'concept': 'us-gaap_CommonStocksIncludingAdditionalPaidInCapital',
#      'unit': 'usd',
#      'label': 'Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 16,207,568 and 16,426,786 shares issued and outstanding, respectively',
#      'value': 61181000000.0},
#     {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit',
#      'unit': 'usd',
#      'label': 'Retained earnings',
#      'value': 12712000000.0},
#     {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax',
#      'unit': 'usd',
#      'label': 'Accumulated other comprehensive income/(loss)',
#      'value': -6494000000.0},
#     {'concept': 'us-gaap_StockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total shareholders’ equity',
#      'value': 67399000000.0},
#     {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total liabilities and shareholders’ equity',
#      'value': 350662000000.0}],
#    'ic': [{'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax',
#      'unit': 'usd',
#      'label': 'Net sales',
#      'value': 221223000000.0},
#     {'concept': 'us-gaap_CostOfGoodsAndServicesSold',
#      'unit': 'usd',
#      'label': 'Cost of sales',
#      'value': 124421000000.0},
#     {'concept': 'us-gaap_GrossProfit',
#      'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 96802000000.0},
#     {'concept': 'us-gaap_ResearchAndDevelopmentExpense',
#      'unit': 'usd',
#      'label': 'Research and development',
#      'value': 12693000000.0},
#     {'concept': 'us-gaap_SellingGeneralAndAdministrativeExpense',
#      'unit': 'usd',
#      'label': 'Selling, general and administrative',
#      'value': 12642000000.0},
#     {'concept': 'us-gaap_OperatingExpenses',
#      'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 25335000000.0},
#     {'concept': 'us-gaap_OperatingIncomeLoss',
#      'unit': 'usd',
#      'label': 'Operating income',
#      'value': 71467000000.0},
#     {'concept': 'us-gaap_NonoperatingIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other income/(expense), net',
#      'value': -87000000.0},
#     {'concept': 'us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#      'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 71380000000.0},
#     {'concept': 'us-gaap_IncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 11740000000.0},
#     {'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 59640000000.0},
#     {'concept': 'us-gaap_EarningsPerShareBasic',
#      'unit': 'usd/share',
#      'label': 'Basic (in dollars per share)',
#      'value': 3.65},
#     {'concept': 'us-gaap_EarningsPerShareDiluted',
#      'unit': 'usd/share',
#      'label': 'Diluted (in dollars per share)',
#      'value': 3.62},
#     {'concept': 'us-gaap_WeightedAverageNumberOfSharesOutstandingBasic',
#      'unit': 'shares',
#      'label': 'Basic (in shares)',
#      'value': 16335263000.0},
#     {'concept': 'us-gaap_WeightedAverageNumberOfDilutedSharesOutstanding',
#      'unit': 'shares',
#      'label': 'Diluted (in shares)',
#      'value': 16461304000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in foreign currency translation, net of tax',
#      'value': -381000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossbeforeReclassificationafterTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of derivative instruments',
#      'value': 696000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossReclassificationAfterTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': 208000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossafterReclassificationandTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on derivative instruments',
#      'value': 488000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of marketable debt securities',
#      'value': -6809000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': -45000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on marketable debt securities',
#      'value': -6764000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent',
#      'unit': 'usd',
#      'label': 'Total other comprehensive income/(loss)',
#      'value': -6657000000.0},
#     {'concept': 'us-gaap_ComprehensiveIncomeNetOfTax',
#      'unit': 'usd',
#      'label': 'Total comprehensive income',
#      'value': 52983000000.0}],
#    'cf': [{'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 59640000000.0},
#     {'concept': 'us-gaap_DepreciationDepletionAndAmortization',
#      'unit': 'usd',
#      'label': 'Depreciation and amortization',
#      'value': 5434000000.0},
#     {'concept': 'us-gaap_ShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Share-based compensation expense',
#      'value': 4517000000.0},
#     {'concept': 'us-gaap_DeferredIncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Deferred income tax expense/(benefit)',
#      'value': 1088000000.0},
#     {'concept': 'us-gaap_OtherNoncashIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': 20000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsReceivable',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': -5542000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInInventories',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': -1065000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherReceivables',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': -643000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingAssets',
#      'unit': 'usd',
#      'label': 'Other current and non-current assets',
#      'value': 3542000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsPayable',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': -1750000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInContractWithCustomerLiability',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 627000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingLiabilities',
#      'unit': 'usd',
#      'label': 'Other current and non-current liabilities',
#      'value': 1888000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInOperatingActivities',
#      'unit': 'usd',
#      'label': 'Cash generated by operating activities',
#      'value': 75132000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Purchases of marketable securities',
#      'value': 61987000000.0},
#     {'concept': 'us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities',
#      'unit': 'usd',
#      'label': 'Proceeds from maturities of marketable securities',
#      'value': 18000000000.0},
#     {'concept': 'us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Proceeds from sales of marketable securities',
#      'value': 24668000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquirePropertyPlantAndEquipment',
#      'unit': 'usd',
#      'label': 'Payments for acquisition of property, plant and equipment',
#      'value': 5317000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquireBusinessesNetOfCashAcquired',
#      'unit': 'usd',
#      'label': 'Payments made in connection with business acquisitions, net',
#      'value': 167000000.0},
#     {'concept': 'us-gaap_PaymentsForProceedsFromOtherInvestingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': 568000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInInvestingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in investing activities',
#      'value': -25371000000.0},
#     {'concept': 'us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Payments for taxes related to net share settlement of equity awards',
#      'value': 3218000000.0},
#     {'concept': 'us-gaap_PaymentsOfDividends',
#      'unit': 'usd',
#      'label': 'Payments for dividends and dividend equivalents',
#      'value': 7327000000.0},
#     {'concept': 'us-gaap_PaymentsForRepurchaseOfCommonStock',
#      'unit': 'usd',
#      'label': 'Repurchases of common stock',
#      'value': 43109000000.0},
#     {'concept': 'us-gaap_ProceedsFromIssuanceOfLongTermDebt',
#      'unit': 'usd',
#      'label': 'Proceeds from issuance of term debt, net',
#      'value': 0.0},
#     {'concept': 'us-gaap_RepaymentsOfLongTermDebt',
#      'unit': 'usd',
#      'label': 'Repayments of term debt',
#      'value': 3750000000.0},
#     {'concept': 'us-gaap_ProceedsFromRepaymentsOfCommercialPaper',
#      'unit': 'usd',
#      'label': 'Proceeds from commercial paper, net',
#      'value': 999000000.0},
#     {'concept': 'us-gaap_ProceedsFromPaymentsForOtherFinancingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': -105000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInFinancingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in financing activities',
#      'value': -56510000000.0},
#     {'concept': 'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect',
#      'unit': 'usd',
#      'label': 'Increase/(Decrease) in cash, cash equivalents and restricted cash',
#      'value': -6749000000.0},
#     {'concept': 'us-gaap_IncomeTaxesPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for income taxes, net',
#      'value': 9301000000.0},
#     {'concept': 'us-gaap_InterestPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for interest',
#      'value': 1406000000.0}]}},
#  {'accessNumber': '0000320193-22-000007',
#   'symbol': 'AAPL',
#   'cik': '320193',
#   'year': 2022,
#   'quarter': 1,
#   'form': '10-Q',
#   'startDate': '2021-09-26 00:00:00',
#   'endDate': '2021-12-25 00:00:00',
#   'filedDate': '2022-01-28 00:00:00',
#   'acceptedDate': '2022-01-27 18:00:58',
#   'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue',
#      'unit': 'usd',
#      'label': 'Cash and cash equivalents',
#      'value': 37119000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesCurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 26794000000.0},
#     {'concept': 'us-gaap_AccountsReceivableNetCurrent',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': 30213000000.0},
#     {'concept': 'us-gaap_InventoryNet',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': 5876000000.0},
#     {'concept': 'us-gaap_NontradeReceivablesCurrent',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': 35040000000.0},
#     {'concept': 'us-gaap_OtherAssetsCurrent',
#      'unit': 'usd',
#      'label': 'Other current assets',
#      'value': 18112000000.0},
#     {'concept': 'us-gaap_AssetsCurrent',
#      'unit': 'usd',
#      'label': 'Total current assets',
#      'value': 153154000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 138683000000.0},
#     {'concept': 'us-gaap_PropertyPlantAndEquipmentNet',
#      'unit': 'usd',
#      'label': 'Property, plant and equipment, net',
#      'value': 39245000000.0},
#     {'concept': 'us-gaap_OtherAssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current assets',
#      'value': 50109000000.0},
#     {'concept': 'us-gaap_AssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current assets',
#      'value': 228037000000.0},
#     {'concept': 'us-gaap_Assets',
#      'unit': 'usd',
#      'label': 'Total assets',
#      'value': 381191000000.0},
#     {'concept': 'us-gaap_AccountsPayableCurrent',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': 74362000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Other current liabilities',
#      'value': 49167000000.0},
#     {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 7876000000.0},
#     {'concept': 'us-gaap_CommercialPaper',
#      'unit': 'usd',
#      'label': 'Commercial paper',
#      'value': 5000000000.0},
#     {'concept': 'us-gaap_LongTermDebtCurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 11169000000.0},
#     {'concept': 'us-gaap_LiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Total current liabilities',
#      'value': 147574000000.0},
#     {'concept': 'us-gaap_LongTermDebtNoncurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 106629000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current liabilities',
#      'value': 55056000000.0},
#     {'concept': 'us-gaap_LiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current liabilities',
#      'value': 161685000000.0},
#     {'concept': 'us-gaap_Liabilities',
#      'unit': 'usd',
#      'label': 'Total liabilities',
#      'value': 309259000000.0},
#     {'concept': 'us-gaap_CommonStocksIncludingAdditionalPaidInCapital',
#      'unit': 'usd',
#      'label': 'Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 16,340,851 and 16,426,786 shares issued and outstanding, respectively',
#      'value': 58424000000.0},
#     {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit',
#      'unit': 'usd',
#      'label': 'Retained earnings',
#      'value': 14435000000.0},
#     {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax',
#      'unit': 'usd',
#      'label': 'Accumulated other comprehensive income/(loss)',
#      'value': -927000000.0},
#     {'concept': 'us-gaap_StockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total shareholders’ equity',
#      'value': 71932000000.0},
#     {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total liabilities and shareholders’ equity',
#      'value': 381191000000.0}],
#    'ic': [{'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax',
#      'unit': 'usd',
#      'label': 'Net sales',
#      'value': 123945000000.0},
#     {'concept': 'us-gaap_CostOfGoodsAndServicesSold',
#      'unit': 'usd',
#      'label': 'Cost of sales',
#      'value': 69702000000.0},
#     {'concept': 'us-gaap_GrossProfit',
#      'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 54243000000.0},
#     {'concept': 'us-gaap_ResearchAndDevelopmentExpense',
#      'unit': 'usd',
#      'label': 'Research and development',
#      'value': 6306000000.0},
#     {'concept': 'us-gaap_SellingGeneralAndAdministrativeExpense',
#      'unit': 'usd',
#      'label': 'Selling, general and administrative',
#      'value': 6449000000.0},
#     {'concept': 'us-gaap_OperatingExpenses',
#      'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 12755000000.0},
#     {'concept': 'us-gaap_OperatingIncomeLoss',
#      'unit': 'usd',
#      'label': 'Operating income',
#      'value': 41488000000.0},
#     {'concept': 'us-gaap_NonoperatingIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other income/(expense), net',
#      'value': -247000000.0},
#     {'concept': 'us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#      'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 41241000000.0},
#     {'concept': 'us-gaap_IncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 6611000000.0},
#     {'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 34630000000.0},
#     {'concept': 'us-gaap_EarningsPerShareBasic',
#      'unit': 'usd/share',
#      'label': 'Basic (in dollars per share)',
#      'value': 2.11},
#     {'concept': 'us-gaap_EarningsPerShareDiluted',
#      'unit': 'usd/share',
#      'label': 'Diluted (in dollars per share)',
#      'value': 2.1},
#     {'concept': 'us-gaap_WeightedAverageNumberOfSharesOutstandingBasic',
#      'unit': 'shares',
#      'label': 'Basic (in shares)',
#      'value': 16391724000.0},
#     {'concept': 'us-gaap_WeightedAverageNumberOfDilutedSharesOutstanding',
#      'unit': 'shares',
#      'label': 'Diluted (in shares)',
#      'value': 16519291000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in foreign currency translation, net of tax',
#      'value': -360000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossbeforeReclassificationafterTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of derivative instruments',
#      'value': 362000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossReclassificationAfterTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': -93000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossafterReclassificationandTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on derivative instruments',
#      'value': 455000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeUnrealizedHoldingGainLossOnSecuritiesArisingDuringPeriodNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of marketable debt securities',
#      'value': -1176000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIForSaleOfSecuritiesNetOfTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
#      'value': 9000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Total change in unrealized gains/losses on marketable debt securities',
#      'value': -1185000000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossNetOfTaxPortionAttributableToParent',
#      'unit': 'usd',
#      'label': 'Total other comprehensive income/(loss)',
#      'value': -1090000000.0},
#     {'concept': 'us-gaap_ComprehensiveIncomeNetOfTax',
#      'unit': 'usd',
#      'label': 'Total comprehensive income',
#      'value': 33540000000.0}],
#    'cf': [{'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 34630000000.0},
#     {'concept': 'us-gaap_DepreciationDepletionAndAmortization',
#      'unit': 'usd',
#      'label': 'Depreciation and amortization',
#      'value': 2697000000.0},
#     {'concept': 'us-gaap_ShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Share-based compensation expense',
#      'value': 2265000000.0},
#     {'concept': 'us-gaap_DeferredIncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Deferred income tax expense/(benefit)',
#      'value': 682000000.0},
#     {'concept': 'us-gaap_OtherNoncashIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': -167000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsReceivable',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': 3934000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInInventories',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': -681000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherReceivables',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': 9812000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingAssets',
#      'unit': 'usd',
#      'label': 'Other current and non-current assets',
#      'value': 4921000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInAccountsPayable',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': 19813000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInContractWithCustomerLiability',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 462000000.0},
#     {'concept': 'us-gaap_IncreaseDecreaseInOtherOperatingLiabilities',
#      'unit': 'usd',
#      'label': 'Other current and non-current liabilities',
#      'value': 4236000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInOperatingActivities',
#      'unit': 'usd',
#      'label': 'Cash generated by operating activities',
#      'value': 46966000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Purchases of marketable securities',
#      'value': 34913000000.0},
#     {'concept': 'us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities',
#      'unit': 'usd',
#      'label': 'Proceeds from maturities of marketable securities',
#      'value': 11309000000.0},
#     {'concept': 'us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt',
#      'unit': 'usd',
#      'label': 'Proceeds from sales of marketable securities',
#      'value': 10675000000.0},
#     {'concept': 'us-gaap_PaymentsToAcquirePropertyPlantAndEquipment',
#      'unit': 'usd',
#      'label': 'Payments for acquisition of property, plant and equipment',
#      'value': 2803000000.0},
#     {'concept': 'us-gaap_PaymentsForProceedsFromOtherInvestingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': 374000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInInvestingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in investing activities',
#      'value': -16106000000.0},
#     {'concept': 'us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation',
#      'unit': 'usd',
#      'label': 'Payments for taxes related to net share settlement of equity awards',
#      'value': 2888000000.0},
#     {'concept': 'us-gaap_PaymentsOfDividends',
#      'unit': 'usd',
#      'label': 'Payments for dividends and dividend equivalents',
#      'value': 3732000000.0},
#     {'concept': 'us-gaap_PaymentsForRepurchaseOfCommonStock',
#      'unit': 'usd',
#      'label': 'Repurchases of common stock',
#      'value': 20478000000.0},
#     {'concept': 'us-gaap_RepaymentsOfLongTermDebt',
#      'unit': 'usd',
#      'label': 'Repayments of term debt',
#      'value': 0.0},
#     {'concept': 'us-gaap_ProceedsFromRepaymentsOfCommercialPaper',
#      'unit': 'usd',
#      'label': 'Proceeds from/(Repayments of) commercial paper, net',
#      'value': -1000000000.0},
#     {'concept': 'us-gaap_ProceedsFromPaymentsForOtherFinancingActivities',
#      'unit': 'usd',
#      'label': 'Other',
#      'value': -61000000.0},
#     {'concept': 'us-gaap_NetCashProvidedByUsedInFinancingActivities',
#      'unit': 'usd',
#      'label': 'Cash used in financing activities',
#      'value': -28159000000.0},
#     {'concept': 'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect',
#      'unit': 'usd',
#      'label': 'Increase/(Decrease) in cash, cash equivalents and restricted cash',
#      'value': 2701000000.0},
#     {'concept': 'us-gaap_IncomeTaxesPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for income taxes, net',
#      'value': 5235000000.0},
#     {'concept': 'us-gaap_InterestPaidNet',
#      'unit': 'usd',
#      'label': 'Cash paid for interest',
#      'value': 531000000.0}]}},
#  {'accessNumber': '0000320193-21-000065',
#   'symbol': 'AAPL',
#   'cik': '320193',
#   'year': 2021,
#   'quarter': 3,
#   'form': '10-Q',
#   'startDate': '2020-09-27 00:00:00',
#   'endDate': '2021-06-26 00:00:00',
#   'filedDate': '2021-07-28 00:00:00',
#   'acceptedDate': '2021-07-27 18:03:42',
#   'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue',
#      'unit': 'usd',
#      'label': 'Cash and cash equivalents',
#      'value': 34050000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesCurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 27646000000.0},
#     {'concept': 'us-gaap_AccountsReceivableNetCurrent',
#      'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': 17475000000.0},
#     {'concept': 'us-gaap_InventoryNet',
#      'unit': 'usd',
#      'label': 'Inventories',
#      'value': 5178000000.0},
#     {'concept': 'us-gaap_NontradeReceivablesCurrent',
#      'unit': 'usd',
#      'label': 'Vendor non-trade receivables',
#      'value': 16433000000.0},
#     {'concept': 'us-gaap_OtherAssetsCurrent',
#      'unit': 'usd',
#      'label': 'Other current assets',
#      'value': 13641000000.0},
#     {'concept': 'us-gaap_AssetsCurrent',
#      'unit': 'usd',
#      'label': 'Total current assets',
#      'value': 114423000000.0},
#     {'concept': 'us-gaap_MarketableSecuritiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Marketable securities',
#      'value': 131948000000.0},
#     {'concept': 'us-gaap_PropertyPlantAndEquipmentNet',
#      'unit': 'usd',
#      'label': 'Property, plant and equipment, net',
#      'value': 38615000000.0},
#     {'concept': 'us-gaap_OtherAssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current assets',
#      'value': 44854000000.0},
#     {'concept': 'us-gaap_AssetsNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current assets',
#      'value': 215417000000.0},
#     {'concept': 'us-gaap_Assets',
#      'unit': 'usd',
#      'label': 'Total assets',
#      'value': 329840000000.0},
#     {'concept': 'us-gaap_AccountsPayableCurrent',
#      'unit': 'usd',
#      'label': 'Accounts payable',
#      'value': 40409000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Other current liabilities',
#      'value': 43625000000.0},
#     {'concept': 'us-gaap_ContractWithCustomerLiabilityCurrent',
#      'unit': 'usd',
#      'label': 'Deferred revenue',
#      'value': 7681000000.0},
#     {'concept': 'us-gaap_CommercialPaper',
#      'unit': 'usd',
#      'label': 'Commercial paper',
#      'value': 8000000000.0},
#     {'concept': 'us-gaap_LongTermDebtCurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 8039000000.0},
#     {'concept': 'us-gaap_LiabilitiesCurrent',
#      'unit': 'usd',
#      'label': 'Total current liabilities',
#      'value': 107754000000.0},
#     {'concept': 'us-gaap_LongTermDebtNoncurrent',
#      'unit': 'usd',
#      'label': 'Term debt',
#      'value': 105752000000.0},
#     {'concept': 'us-gaap_OtherLiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Other non-current liabilities',
#      'value': 52054000000.0},
#     {'concept': 'us-gaap_LiabilitiesNoncurrent',
#      'unit': 'usd',
#      'label': 'Total non-current liabilities',
#      'value': 157806000000.0},
#     {'concept': 'us-gaap_Liabilities',
#      'unit': 'usd',
#      'label': 'Total liabilities',
#      'value': 265560000000.0},
#     {'concept': 'us-gaap_CommonStocksIncludingAdditionalPaidInCapital',
#      'unit': 'usd',
#      'label': 'Common stock and additional paid-in capital, $0.00001 par value: 50,400,000 shares authorized; 16,556,942 and 16,976,763 shares issued and outstanding, respectively',
#      'value': 54989000000.0},
#     {'concept': 'us-gaap_RetainedEarningsAccumulatedDeficit',
#      'unit': 'usd',
#      'label': 'Retained earnings',
#      'value': 9233000000.0},
#     {'concept': 'us-gaap_AccumulatedOtherComprehensiveIncomeLossNetOfTax',
#      'unit': 'usd',
#      'label': 'Accumulated other comprehensive income/(loss)',
#      'value': 58000000.0},
#     {'concept': 'us-gaap_StockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total shareholders’ equity',
#      'value': 64280000000.0},
#     {'concept': 'us-gaap_LiabilitiesAndStockholdersEquity',
#      'unit': 'usd',
#      'label': 'Total liabilities and shareholders’ equity',
#      'value': 329840000000.0}],
#    'ic': [{'concept': 'us-gaap_RevenueFromContractWithCustomerExcludingAssessedTax',
#      'unit': 'usd',
#      'label': 'Net sales',
#      'value': 282457000000.0},
#     {'concept': 'us-gaap_CostOfGoodsAndServicesSold',
#      'unit': 'usd',
#      'label': 'Cost of sales',
#      'value': 164795000000.0},
#     {'concept': 'us-gaap_GrossProfit',
#      'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 117662000000.0},
#     {'concept': 'us-gaap_ResearchAndDevelopmentExpense',
#      'unit': 'usd',
#      'label': 'Research and development',
#      'value': 16142000000.0},
#     {'concept': 'us-gaap_SellingGeneralAndAdministrativeExpense',
#      'unit': 'usd',
#      'label': 'Selling, general and administrative',
#      'value': 16357000000.0},
#     {'concept': 'us-gaap_OperatingExpenses',
#      'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 32499000000.0},
#     {'concept': 'us-gaap_OperatingIncomeLoss',
#      'unit': 'usd',
#      'label': 'Operating income',
#      'value': 85163000000.0},
#     {'concept': 'us-gaap_NonoperatingIncomeExpense',
#      'unit': 'usd',
#      'label': 'Other income/(expense), net',
#      'value': 796000000.0},
#     {'concept': 'us-gaap_IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest',
#      'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 85959000000.0},
#     {'concept': 'us-gaap_IncomeTaxExpenseBenefit',
#      'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 11830000000.0},
#     {'concept': 'us-gaap_NetIncomeLoss',
#      'unit': 'usd',
#      'label': 'Net income',
#      'value': 74129000000.0},
#     {'concept': 'us-gaap_EarningsPerShareBasic',
#      'unit': 'usd/share',
#      'label': 'Basic (in dollars per share)',
#      'value': 4.42},
#     {'concept': 'us-gaap_EarningsPerShareDiluted',
#      'unit': 'usd/share',
#      'label': 'Diluted (in dollars per share)',
#      'value': 4.38},
#     {'concept': 'us-gaap_WeightedAverageNumberOfSharesOutstandingBasic',
#      'unit': 'shares',
#      'label': 'Basic (in shares)',
#      'value': 16772656000.0},
#     {'concept': 'us-gaap_WeightedAverageNumberOfDilutedSharesOutstanding',
#      'unit': 'shares',
#      'label': 'Diluted (in shares)',
#      'value': 16941527000.0},
#     {'concept': 'us-gaap_OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationAdjustmentNetOfTax',
#      'unit': 'usd',
#      'label': 'Change in foreign currency translation, net of tax',
#      'value': 659000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossbeforeReclassificationafterTax',
#      'unit': 'usd',
#      'label': 'Change in fair value of derivatives',
#      'value': 4000000.0},
#     {'concept': 'aapl_OtherComprehensiveIncomeLossDerivativeInstrumentGainLossReclassificationAfterTax',
#      'unit': 'usd',
#      'label': 'Adjustment for net (gains)/losses realized and included in net income',
# ...
#     {'unit': 'usd',
#      'label': 'Proceeds from issuance of common stock',
#      'value': 733000000,
#      'concept': 'ProceedsFromIssuanceOfCommonStock'},
#     {'unit': 'usd',
#      'label': 'Excess tax benefits from stock-based compensation',
#      'value': 652000000,
#      'concept': 'ExcessTaxBenefitFromShareBasedCompensationFinancingActivities'},
#     {'unit': 'usd',
#      'label': 'Taxes paid related to net share settlement of equity awards',
#      'value': -384000000,
#      'concept': 'EmployeeServiceShareBasedCompensationCashFlowEffectCashUsedToSettleAwards'},
#     {'unit': 'usd',
#      'label': 'Cash generated by financing activities',
#      'value': 1001000000,
#      'concept': 'NetCashProvidedByUsedInFinancingActivities'},
#     {'unit': 'usd',
#      'label': 'Purchases of marketable securities',
#      'value': 41318000000,
#      'concept': 'PaymentsToAcquireAvailableForSaleSecuritiesDebt'},
#     {'unit': 'usd',
#      'label': 'Proceeds from maturities of marketable securities',
#      'value': 19758000000,
#      'concept': 'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities'},
#     {'unit': 'usd',
#      'label': 'Proceeds from sales of marketable securities',
#      'value': 14048000000,
#      'concept': 'ProceedsFromSaleOfAvailableForSaleSecuritiesDebt'},
#     {'unit': 'usd',
#      'label': 'Purchases of other long-term investments',
#      'value': 10000000,
#      'concept': 'PaymentsToAcquireOtherInvestments'},
#     {'unit': 'usd',
#      'label': 'Business acquisitions aggregate cash considerarion, aggregate cash consideration, net of cash acquired',
#      'value': 615000000,
#      'concept': 'PaymentsToAcquireBusinessesNetOfCashAcquired'},
#     {'unit': 'usd',
#      'label': 'Cash payments for capital asset purchases',
#      'value': 1245000000,
#      'concept': 'PaymentsToAcquireProductiveAssets'},
#     {'unit': 'usd',
#      'label': 'Payments for acquisition of intangible assets',
#      'value': 63000000,
#      'concept': 'PaymentsToAcquireIntangibleAssets'},
#     {'unit': 'usd',
#      'label': 'Other',
#      'value': 26000000,
#      'concept': 'PaymentsForProceedsFromOtherInvestingActivities'},
#     {'unit': 'usd',
#      'label': 'Cash used in investing activities',
#      'value': -9471000000,
#      'concept': 'NetCashProvidedByUsedInInvestingActivities'},
#     {'unit': 'usd',
#      'label': 'Net income',
#      'value': 9705000000,
#      'concept': 'NetIncomeLoss'},
#     {'unit': 'usd',
#      'label': 'Cash generated by operating activities',
#      'value': 12912000000,
#      'concept': 'NetCashProvidedByUsedInOperatingActivities'},
#     {'unit': 'usd',
#      'label': 'Increase/(decrease) in cash and cash equivalents',
#      'value': 4442000000,
#      'concept': 'CashAndCashEquivalentsPeriodIncreaseDecrease'},
#     {'unit': 'usd',
#      'label': 'Cash paid for income taxes, net',
#      'value': 2657000000,
#      'concept': 'IncomeTaxesPaidNet'}],
#    'ic': [{'unit': 'usd/shares',
#      'label': 'Basic earnings per common share',
#      'value': 10.69,
#      'concept': 'EarningsPerShareBasic'},
#     {'unit': 'usd/shares',
#      'label': 'Diluted earnings per common share',
#      'value': 10.51,
#      'concept': 'EarningsPerShareDiluted'},
#     {'unit': 'usd',
#      'label': 'Research and Development Expense',
#      'value': 1288000000,
#      'concept': 'ResearchAndDevelopmentExpense'},
#     {'unit': 'usd',
#      'label': 'Selling, General and Administrative Expense',
#      'value': 3946000000,
#      'concept': 'SellingGeneralAndAdministrativeExpense'},
#     {'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 5234000000,
#      'concept': 'OperatingExpenses'},
#     {'unit': 'usd',
#      'label': 'Sales Revenue, Net',
#      'value': 44882000000,
#      'concept': 'SalesRevenueNet'},
#     {'unit': 'usd',
#      'label': 'Cost of Goods and Services Sold',
#      'value': 26710000000,
#      'concept': 'CostOfGoodsAndServicesSold'},
#     {'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 18172000000,
#      'concept': 'GrossProfit'},
#     {'unit': 'usd',
#      'label': 'Operating income',
#      'value': 12938000000,
#      'concept': 'OperatingIncomeLoss'},
#     {'unit': 'usd',
#      'label': 'Nonoperating Income (Expense)',
#      'value': 141000000,
#      'concept': 'NonoperatingIncomeExpense'},
#     {'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 13079000000,
#      'concept': 'IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments'},
#     {'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 3374000000,
#      'concept': 'IncomeTaxExpenseBenefit'},
#     {'unit': 'usd',
#      'label': 'Net income',
#      'value': 9705000000,
#      'concept': 'NetIncomeLoss'},
#     {'unit': 'shares',
#      'label': 'Weighted-average shares outstanding',
#      'value': 907762000,
#      'concept': 'WeightedAverageNumberOfSharesOutstandingBasic'},
#     {'unit': 'shares',
#      'label': 'Diluted',
#      'value': 923341000,
#      'concept': 'WeightedAverageNumberOfDilutedSharesOutstanding'}]}},
#  {'accessNumber': '0001193125-10-088957',
#   'symbol': 'AAPL',
#   'cik': '320193',
#   'year': 2010,
#   'quarter': 2,
#   'form': '10-Q',
#   'startDate': '2009-09-27 00:00:00',
#   'endDate': '2010-03-27 00:00:00',
#   'filedDate': '2010-04-21 00:00:00',
#   'acceptedDate': '2010-04-21 16:39:23',
#   'report': {'bs': [{'unit': 'usd',
#      'label': 'Long-term marketable securities',
#      'value': 18549000000,
#      'concept': 'AvailableForSaleSecuritiesNoncurrent'},
#     {'unit': 'usd',
#      'label': 'Tangible assets that are held by an entity for use in the production or supply of goods and services, for rental to others, or for administrative purposes and that are expected to provide economic benefit for more than one year; net of accumulated depreciation. Examples include land, buildings, and production equipment. Also includes software programs or applications for internal use (that is, not to be sold, leased or otherwise marketed to others) that qualify for capitalization.',
#      'value': 3504000000,
#      'concept': 'aapl:PropertyPlantAndEquipmentAndCapitalizedSoftwareNet'},
#     {'unit': 'usd',
#      'label': 'Goodwill',
#      'value': 480000000,
#      'concept': 'Goodwill'},
#     {'unit': 'usd',
#      'label': 'Acquired intangible assets, net',
#      'value': 263000000,
#      'concept': 'IntangibleAssetsNetExcludingGoodwill'},
#     {'unit': 'usd',
#      'label': 'Other assets',
#      'value': 1925000000,
#      'concept': 'OtherAssetsNoncurrent'},
#     {'unit': 'usd',
#      'label': 'Total assets',
#      'value': 57057000000,
#      'concept': 'Assets'},
#     {'unit': 'usd',
#      'label': 'Cash and cash equivalents',
#      'value': 10018000000,
#      'concept': 'CashAndCashEquivalentsAtCarryingValue'},
#     {'unit': 'usd',
#      'label': 'Short-term marketable securities',
#      'value': 13137000000,
#      'concept': 'AvailableForSaleSecuritiesCurrent'},
#     {'unit': 'usd',
#      'label': 'Accounts receivable, less allowances of $57 and $52, respectively',
#      'value': 2886000000,
#      'concept': 'AccountsReceivableNetCurrent'},
#     {'unit': 'usd',
#      'label': 'Inventories',
#      'value': 638000000,
#      'concept': 'InventoryNet'},
#     {'unit': 'usd',
#      'label': 'Deferred tax assets',
#      'value': 1142000000,
#      'concept': 'DeferredTaxAssetsNetCurrent'},
#     {'unit': 'usd',
#      'label': 'Other current assets',
#      'value': 4515000000,
#      'concept': 'OtherAssetsCurrent'},
#     {'unit': 'usd',
#      'label': 'Total current assets',
#      'value': 32336000000,
#      'concept': 'AssetsCurrent'},
#     {'unit': 'usd',
#      'label': 'Deferred revenue - non-current',
#      'value': 941000000,
#      'concept': 'DeferredRevenueNoncurrent'},
#     {'unit': 'usd',
#      'label': 'Other non-current liabilities',
#      'value': 4539000000,
#      'concept': 'OtherLiabilitiesNoncurrent'},
#     {'unit': 'usd',
#      'label': 'Total liabilities',
#      'value': 17709000000,
#      'concept': 'Liabilities'},
#     {'unit': 'usd',
#      'label': "Total liabilities and shareholders' equity",
#      'value': 57057000000,
#      'concept': 'LiabilitiesAndStockholdersEquity'},
#     {'unit': 'usd',
#      'label': 'Accounts Payable, Current',
#      'value': 5666000000,
#      'concept': 'AccountsPayableCurrent'},
#     {'unit': 'usd',
#      'label': 'Accrued expenses',
#      'value': 4021000000,
#      'concept': 'AccruedLiabilitiesCurrent'},
#     {'unit': 'usd',
#      'label': 'Deferred Revenue, Current',
#      'value': 2542000000,
#      'concept': 'DeferredRevenueCurrent'},
#     {'unit': 'usd',
#      'label': 'Total current liabilities',
#      'value': 12229000000,
#      'concept': 'LiabilitiesCurrent'},
#     {'unit': 'usd',
#      'label': 'Common stock, no par value; 1,800,000,000 shares authorized; 909,635,811 and 899,805,500 shares issued and outstanding, respectively',
#      'value': 9553000000,
#      'concept': 'CommonStockValue'},
#     {'unit': 'usd',
#      'label': 'Retained earnings',
#      'value': 29670000000,
#      'concept': 'RetainedEarningsAccumulatedDeficit'},
#     {'unit': 'usd',
#      'label': 'Accumulated other comprehensive income',
#      'value': 125000000,
#      'concept': 'AccumulatedOtherComprehensiveIncomeLossNetOfTax'},
#     {'unit': 'usd',
#      'label': "Total shareholders' equity",
#      'value': 39348000000,
#      'concept': 'StockholdersEquity'}],
#    'cf': [{'unit': 'usd',
#      'label': 'Depreciation, amortization and accretion',
#      'value': 425000000,
#      'concept': 'DepreciationAmortizationAndAccretionNet'},
#     {'unit': 'usd',
#      'label': 'Stock-based compensation expense',
#      'value': 436000000,
#      'concept': 'ShareBasedCompensation'},
#     {'unit': 'usd',
#      'label': 'Deferred income tax expense',
#      'value': 893000000,
#      'concept': 'DeferredIncomeTaxExpenseBenefit'},
#     {'unit': 'usd',
#      'label': 'Loss on disposition of property, plant and equipment',
#      'value': -9000000,
#      'concept': 'GainLossOnSaleOfPropertyPlantEquipment'},
#     {'unit': 'usd',
#      'label': 'Accounts receivable, net',
#      'value': -482000000,
#      'concept': 'IncreaseDecreaseInAccountsReceivable'},
#     {'unit': 'usd',
#      'label': 'Increase (Decrease) in Inventories',
#      'value': 183000000,
#      'concept': 'IncreaseDecreaseInInventories'},
#     {'unit': 'usd',
#      'label': 'The net change during the reporting period in other current assets.',
#      'value': 824000000,
#      'concept': 'aapl:IncreaseDecreaseOtherCurrentAssets'},
#     {'unit': 'usd',
#      'label': 'Increase (Decrease) in Other Operating Assets',
#      'value': -149000000,
#      'concept': 'IncreaseDecreaseInOtherOperatingAssets'},
#     {'unit': 'usd',
#      'label': 'Increase (Decrease) in Accounts Payable',
#      'value': -18000000,
#      'concept': 'IncreaseDecreaseInAccountsPayable'},
#     {'unit': 'usd',
#      'label': 'Increase (Decrease) in Deferred Revenue',
#      'value': 577000000,
#      'concept': 'IncreaseDecreaseInDeferredRevenue'},
#     {'unit': 'usd',
#      'label': 'Other liabilities',
#      'value': -287000000,
#      'concept': 'IncreaseDecreaseInOtherOperatingLiabilities'},
#     {'unit': 'usd',
#      'label': 'Proceeds from issuance of common stock',
#      'value': 534000000,
#      'concept': 'ProceedsFromIssuanceOfCommonStock'},
#     {'unit': 'usd',
#      'label': 'Excess tax benefits from stock-based compensation',
#      'value': 413000000,
#      'concept': 'ExcessTaxBenefitFromShareBasedCompensationFinancingActivities'},
#     {'unit': 'usd',
#      'label': 'Cash used to net share settle equity awards',
#      'value': -262000000,
#      'concept': 'EmployeeServiceShareBasedCompensationCashFlowEffectCashUsedToSettleAwards'},
#     {'unit': 'usd',
#      'label': 'Cash generated by financing activities',
#      'value': 685000000,
#      'concept': 'NetCashProvidedByUsedInFinancingActivities'},
#     {'unit': 'usd',
#      'label': 'Purchases of marketable securities',
#      'value': 25061000000,
#      'concept': 'PaymentsToAcquireAvailableForSaleSecurities'},
#     {'unit': 'usd',
#      'label': 'Proceeds from maturities of marketable securities',
#      'value': 13331000000,
#      'concept': 'ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities'},
#     {'unit': 'usd',
#      'label': 'Proceeds from sales of marketable securities',
#      'value': 8686000000,
#      'concept': 'ProceedsFromSaleOfAvailableForSaleSecurities'},
#     {'unit': 'usd',
#      'label': 'Purchases of other long-term investments',
#      'value': 9000000,
#      'concept': 'PaymentsToAcquireOtherInvestments'},
#     {'unit': 'usd',
#      'label': 'Payments made in connection with business acquisitions, net of cash acquired',
#      'value': 325000000,
#      'concept': 'PaymentsToAcquireBusinessesNetOfCashAcquired'},
#     {'unit': 'usd',
#      'label': 'Payment for acquisition of property, plant and equipment',
#      'value': 650000000,
#      'concept': 'PaymentsToAcquireProductiveAssets'},
#     {'unit': 'usd',
#      'label': 'Payment for acquisition of intangible assets',
#      'value': 32000000,
#      'concept': 'PaymentsToAcquireIntangibleAssets'},
#     {'unit': 'usd',
#      'label': 'Other',
#      'value': -19000000,
#      'concept': 'PaymentsForProceedsFromOtherInvestingActivities'},
#     {'unit': 'usd',
#      'label': 'Cash used in investing activities',
#      'value': -4041000000,
#      'concept': 'NetCashProvidedByUsedInInvestingActivities'},
#     {'unit': 'usd',
#      'label': 'Net income',
#      'value': 6452000000,
#      'concept': 'NetIncomeLoss'},
#     {'unit': 'usd',
#      'label': 'Cash generated by operating activities',
#      'value': 8111000000,
#      'concept': 'NetCashProvidedByUsedInOperatingActivities'},
#     {'unit': 'usd',
#      'label': 'Increase/(decrease) in cash and cash equivalents',
#      'value': 4755000000,
#      'concept': 'CashAndCashEquivalentsPeriodIncreaseDecrease'},
#     {'unit': 'usd',
#      'label': 'Cash paid for income taxes, net',
#      'value': 2144000000,
#      'concept': 'IncomeTaxesPaidNet'}],
#    'ic': [{'unit': 'usd/shares',
#      'label': 'Earnings Per Share, Basic',
#      'value': 7.12,
#      'concept': 'EarningsPerShareBasic'},
#     {'unit': 'usd/shares',
#      'label': 'Earnings Per Share, Diluted',
#      'value': 7,
#      'concept': 'EarningsPerShareDiluted'},
#     {'unit': 'usd',
#      'label': 'Research and development',
#      'value': 824000000,
#      'concept': 'ResearchAndDevelopmentExpense'},
#     {'unit': 'usd',
#      'label': 'Selling, general and administrative',
#      'value': 2508000000,
#      'concept': 'SellingGeneralAndAdministrativeExpense'},
#     {'unit': 'usd',
#      'label': 'Total operating expenses',
#      'value': 3332000000,
#      'concept': 'OperatingExpenses'},
#     {'unit': 'usd',
#      'label': 'Net sales',
#      'value': 29182000000,
#      'concept': 'SalesRevenueNet'},
#     {'unit': 'usd',
#      'label': 'Cost of sales',
#      'value': 17146000000,
#      'concept': 'CostOfGoodsAndServicesSold'},
#     {'unit': 'usd',
#      'label': 'Gross margin',
#      'value': 12036000000,
#      'concept': 'GrossProfit'},
#     {'unit': 'usd',
#      'label': 'Operating income',
#      'value': 8704000000,
#      'concept': 'OperatingIncomeLoss'},
#     {'unit': 'usd',
#      'label': 'Other income and expense',
#      'value': 83000000,
#      'concept': 'NonoperatingIncomeExpense'},
#     {'unit': 'usd',
#      'label': 'Income before provision for income taxes',
#      'value': 8787000000,
#      'concept': 'IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments'},
#     {'unit': 'usd',
#      'label': 'Provision for income taxes',
#      'value': 2335000000,
#      'concept': 'IncomeTaxExpenseBenefit'},
#     {'unit': 'usd',
#      'label': 'Net income',
#      'value': 6452000000,
#      'concept': 'NetIncomeLoss'},
#     {'unit': 'shares',
#      'label': 'Weighted Average Number of Shares Outstanding, Basic',
#      'value': 905545000,
#      'concept': 'WeightedAverageNumberOfSharesOutstandingBasic'},
#     {'unit': 'shares',
#      'label': 'Weighted Average Number of Shares Outstanding, Diluted',
#      'value': 921331000,
#      'concept': 'WeightedAverageNumberOfDilutedSharesOutstanding'}]}}]
